# %%
import matplotlib.pyplot as plt
import numpy as np
x=list(range(1,6))
y=[2.5,3.2,1.2,6.6,3.9]
size=[100,112,1120,150,1350]
color = ["gray","red","blue","green","purple"]

# %%
# กราฟแสดงการกระจายของข้อมูล
plt.scatter(x,y,s=size,c=color)
plt.show()
