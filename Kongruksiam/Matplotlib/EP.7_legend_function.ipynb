# %%
import matplotlib.pyplot as plt
import numpy as np

arr_a = np.arange(1,5)
products_1 = [30,10,20,60,40]
products_2 = [15,20,30,50,66]
months = list(range(1,6))
plt.plot(months,products_1,"go-")
plt.plot(months,products_2,"r*-")

plt.xlabel("Months",size=10,color="c")
plt.ylabel("Sales",size=10,color="m")
config = {"size":15,"color":"w","backgroundcolor":"k"}
plt.title("Top Sale 2024",config,loc="left") 
    # loc = [left,right,center(default)]

# ---------แสดง คำอธิบายเส้น-----------
plt.legend(
    ["Mouse","Keyboard"],
    loc=0,                  # หน้าต่อไป
    
    title="None",           # title = title
    title_fontsize="large",

    fontsize="xx-large",    # fontsize ระบุเป็นตัวเลขก็ได้ หรือจะเป็น [xx-small,x-small,small,medium(default),large,x-large,xx-large]

    facecolor="m",          # facecolor = สีในกรอบ

    edgecolor="k",          # edgecolor = สีเส้นกรอบ

    borderpad=3,            # borderpad = ขนาดของแผ่น legend

    labelspacing=2)         # labelspacing = ระยะห่างของแต่ละเนื้อหา

# ---------แสดง คำอธิบายเส้น-----------

# %%
import pandas as pd
data = [{"Format String":"best (default)", "Code":0, },
        {"Format String":"upper right", "Code":1, },
        {"Format String":"upper left", "Code":2, },
        {"Format String":"lower left", "Code":3, },
        {"Format String":"lower right", "Code":4, },
        {"Format String":"right", "Code":5, },
        {"Format String":"center left", "Code":6, },
        {"Format String":"center right", "Code":7, },
        {"Format String":"lower center", "Code":8, },
        {"Format String":"upper center", "Code":9, },
        {"Format String":"center", "Code":10, }]
df = pd.DataFrame(data)
df.set_index("Format String",inplace=True)
df
# Out:
#                 Code
# Format String
# best (default)     0
# upper right        1
# upper left         2
# lower left         3
# lower right        4
# right              5
# center left        6
# center right       7
# lower center       8
# upper center       9
# center            10
