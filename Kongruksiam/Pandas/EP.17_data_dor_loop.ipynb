# %%
import pandas as pd
import numpy as np

df = pd.read_csv("C:/Programming/Dataset/Tuition_Assistance_20240525.csv");df
# Out:
#                    Department                                Major  \
# 0                      Police                Business/Admin./Mgmt.
# 1                      Police                Business/Admin./Mgmt.
# 2                      Police                Business/Admin./Mgmt.
# 3     Health & Human Services                Business/Admin./Mgmt.
# 4     Health & Human Services                          Other/Misc.
# ...                       ...                                  ...
# 4363                   Police                    Political Science
# 4364     Fire/Rescue Services                                  NaN
# 4365           Liquor Control               Information Technology
# 4366                   Police                          Other/Misc.
# 4367           Transportation  Civil and Environmental Engineering
#
#                         Degree                               School  \
# 0                           AA  Montgomery College Rockville Campus
# ...

# %%
'''
for idx,row in df.iterrows():
    print(idx,row,Name,row,Price)
'''

for idx, row in df.iterrows():
    print("Department = {} and Degree = {}".format(row.Department,row.Degree))
# Out:
# Department = Police and Degree = AA
# Department = Police and Degree = AA
# Department = Police and Degree = AA
# Department = Health & Human Services and Degree = Masters (MA/MS/MPH/etc.)
# Department = Health & Human Services and Degree = Masters (MA/MS/MPH/etc.)
# Department = Finance and Degree = Masters (MA/MS/MPH/etc.)
# Department = Police and Degree = AA
# Department = Health & Human Services and Degree = AA
# Department = County Attorney and Degree = Bachelors (BA/BS)
# Department = Health & Human Services and Degree = Masters (MA/MS/MPH/etc.)
# Department = Health & Human Services and Degree = AA
# Department = County Attorney and Degree = Bachelors (BA/BS)
# Department = County Attorney and Degree = Bachelors (BA/BS)
# Department = Police and Degree = Other
# Department = Health & Human Services and Degree = AA
# Department = Health & Human Services and Degree = Certificate
# Department = Community Use Public Facilities and Degree = Certificate
# ...
