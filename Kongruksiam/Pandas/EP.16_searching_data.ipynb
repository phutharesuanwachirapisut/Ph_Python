# %%
import pandas as pd
import numpy as np

df = pd.read_csv("C:/Programming/Dataset/Tuition_Assistance_20240525.csv");df
# Out:
#                    Department                                Major  \
# 0                      Police                Business/Admin./Mgmt.
# 1                      Police                Business/Admin./Mgmt.
# 2                      Police                Business/Admin./Mgmt.
# 3     Health & Human Services                Business/Admin./Mgmt.
# 4     Health & Human Services                          Other/Misc.
# ...                       ...                                  ...
# 4363                   Police                    Political Science
# 4364     Fire/Rescue Services                                  NaN
# 4365           Liquor Control               Information Technology
# 4366                   Police                          Other/Misc.
# 4367           Transportation  Civil and Environmental Engineering
#
#                         Degree                               School  \
# 0                           AA  Montgomery College Rockville Campus
# ...

# %%
# dataframe.column name.data type.match("คำที่จะค้นหา") ต้องเป็นคำที่ถูต้องครบถ้วนทุกตัวอักษร
    # return Ture or False for each column
df.Department.str.match("Police")
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 4363     True
# 4364    False
# 4365    False
# 4366     True
# 4367    False
# Name: Department, Length: 4368, dtype: bool

# %%
# dataframe.column name.data type.contains("คำที่จะค้นหา") ค่าใกล้เคียงก็ได้
    # return Ture or False for each column

df.Department.str.contains("Po")
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 4363     True
# 4364    False
# 4365    False
# 4366     True
# 4367    False
# Name: Department, Length: 4368, dtype: bool

# %%
# แสดงค่าที่ df.Department.str.contains("Po") == True
df[df.Department.str.contains("Po")]
# Out:
#      Department                            Major             Degree  \
# 0        Police            Business/Admin./Mgmt.                 AA
# 1        Police            Business/Admin./Mgmt.                 AA
# 2        Police            Business/Admin./Mgmt.                 AA
# 6        Police            Business/Admin./Mgmt.                 AA
# 13       Police           Information Technology              Other
# ...         ...                              ...                ...
# 4351     Police  Spanish Language and Literature              Other
# 4357     Police                      Other/Misc.              Other
# 4361     Police                       Psychology  Bachelors (BA/BS)
# 4363     Police                Political Science  Bachelors (BA/BS)
# 4366     Police                      Other/Misc.              Other
#
#                                       School  \
# 0        Montgomery College Rockville Campus
# 1        Montgomery College Rockville Campus
# ...
