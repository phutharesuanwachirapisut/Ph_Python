# %%
"""การตรวจสอบข้อมูล
    dataframe.head()  -> อ่านข้อมูล 5 แถวแรก
    dataframe.head(n) -> อ่านข้อมูล n แถวแรก
    dataframe.tail()  -> อ่านข้อมูล 5 แถวสุดท้าย
    dataframe.tail(n) -> อ่านข้อมูล n แถวสุดท้าย
    dataframe.sample(n)   -> สุ่มจำนวนข้อมูล n แถว (เหมือน r progrmaming)
    dataframe.describe()  -> ดูค่าทางสถิติ เช่น ค่า max min mean etc.
    dataframe.shape   -> สำหรับการนับจำนวนข้อมูล เช่น (20,4) คือ row 20 column 4
    dataframe.columns -> ตรวจสอบว่ามีคอลัมน์อะไรบ้าง แสดงชื่อ column ของ dataframe
    dataframe.valusr  -> อ่านข้อมูลแบบ array ของข้อมูลภายใน dataframe
"""

import pandas as pd

df = pd.read_excel("C:/Programming/Dataset/dataupdate.xlsx",sheet_name="weather",index_col="Day");df
# Out:
#             Temperature  WindSpeed    Event
# Day
# 2020-12-01           30          9  แดดร้อน
# 2020-12-02           28          8   เมฆมาก
# 2020-12-03           27          4     ฝนตก
# 2020-12-04           19          3  แดดร้อน
# 2020-12-05           20          5   เมฆมาก
# 2020-12-06           25          6     ฝนตก
# 2020-12-07           36          4     ฝนตก
# 2020-12-08           28          6     ฝนตก
# 2020-12-09           17          5   เมฆมาก
# 2020-12-10           24          6  แดดร้อน
# 2020-12-11           26          4     ฝนตก
# 2020-12-12           27          9  แดดร้อน
# 2020-12-13           30          2  แดดร้อน
# 2020-12-14           31          5   เมฆมาก
# 2020-12-15           28          4  แดดร้อน
# 2020-12-16           27          7  แดดร้อน
# 2020-12-17           20          8     ฝนตก
# 2020-12-18           18          5     ฝนตก
# 2020-12-19           25          7  แดดร้อน
# 2020-12-20           28          4   เมฆมาก
# ...

# %%
df.head()
# Out:
#             Temperature  WindSpeed    Event
# Day
# 2020-12-01           30          9  แดดร้อน
# 2020-12-02           28          8   เมฆมาก
# 2020-12-03           27          4     ฝนตก
# 2020-12-04           19          3  แดดร้อน
# 2020-12-05           20          5   เมฆมาก

# %%
df.tail()
# Out:
#             Temperature  WindSpeed   Event
# Day
# 2020-12-26           25          8    ฝนตก
# 2020-12-27           28          9  เมฆมาก
# 2020-12-28           30          2  เมฆมาก
# 2020-12-29           31          1    ฝนตก
# 2020-12-30           35          2    ฝนตก

# %%
df.sample(5)
# Out:
#             Temperature  WindSpeed    Event
# Day
# 2020-12-09           17          5   เมฆมาก
# 2020-12-18           18          5     ฝนตก
# 2020-12-22           38          2   เมฆมาก
# 2020-12-24           29          4     ฝนตก
# 2020-12-25           34          5  แดดร้อน

# %%
df.describe()
# Out:
#        Temperature  WindSpeed
# count    30.000000  30.000000
# mean     27.433333   5.066667
# std       5.237026   2.288402
# min      17.000000   1.000000
# 25%      25.000000   4.000000
# 50%      28.000000   5.000000
# 75%      30.000000   6.750000
# max      38.000000   9.000000

# %%
df.shape
# Out:
# (30, 3)

# %%
df.columns
# Out:
# Index(['Temperature', 'WindSpeed', 'Event'], dtype='object')

# %%
df.values
# Out:
# array([[30, 9, 'แดดร้อน'],
#        [28, 8, 'เมฆมาก'],
#        [27, 4, 'ฝนตก'],
#        [19, 3, 'แดดร้อน'],
#        [20, 5, 'เมฆมาก'],
#        [25, 6, 'ฝนตก'],
#        [36, 4, 'ฝนตก'],
#        [28, 6, 'ฝนตก'],
#        [17, 5, 'เมฆมาก'],
#        [24, 6, 'แดดร้อน'],
#        [26, 4, 'ฝนตก'],
#        [27, 9, 'แดดร้อน'],
#        [30, 2, 'แดดร้อน'],
#        [31, 5, 'เมฆมาก'],
#        [28, 4, 'แดดร้อน'],
#        [27, 7, 'แดดร้อน'],
#        [20, 8, 'ฝนตก'],
#        [18, 5, 'ฝนตก'],
#        [25, 7, 'แดดร้อน'],
#        [28, 4, 'เมฆมาก'],
#        [25, 5, 'เมฆมาก'],
#        [38, 2, 'เมฆมาก'],
#        [34, 3, 'ฝนตก'],
#        [29, 4, 'ฝนตก'],
#        [34, 5, 'แดดร้อน'],
#        [25, 8, 'ฝนตก'],
#        [28, 9, 'เมฆมาก'],
#        [30, 2, 'เมฆมาก'],
#        [31, 1, 'ฝนตก'],
#        [35, 2, 'ฝนตก']], dtype=object)

# %%
import pandas as pd
pd.read_csv("kaggle datasets download -d jeanetteponder/world-economic-classifications")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 import pandas as pd
# ----> 2 pd.read_csv("kaggle datasets download -d jeanetteponder/world-economic-classifications")
#
# ...
