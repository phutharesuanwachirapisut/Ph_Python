# %%
# Phutharesuan Wachirapisut
# 651610348
# Lab07_01
# 229323 sec 002

# %%
import pandas as pd
import numpy as np
import json

# Client ID -> d9aeee4a-dc4b-4a91-a4c2-1c815493b58a

# %%
# 2023 เดือนเลขคี่
import http.client

conn1u = http.client.HTTPSConnection("apigw1.bot.or.th")
conn3u = http.client.HTTPSConnection("apigw1.bot.or.th")
conn5u = http.client.HTTPSConnection("apigw1.bot.or.th")
conn7u = http.client.HTTPSConnection("apigw1.bot.or.th")
conn9u = http.client.HTTPSConnection("apigw1.bot.or.th")
conn11u = http.client.HTTPSConnection("apigw1.bot.or.th")

conn1j = http.client.HTTPSConnection("apigw1.bot.or.th")
conn3j = http.client.HTTPSConnection("apigw1.bot.or.th")
conn5j = http.client.HTTPSConnection("apigw1.bot.or.th")
conn7j = http.client.HTTPSConnection("apigw1.bot.or.th")
conn9j = http.client.HTTPSConnection("apigw1.bot.or.th")
conn11j = http.client.HTTPSConnection("apigw1.bot.or.th")

conn1e = http.client.HTTPSConnection("apigw1.bot.or.th")
conn3e = http.client.HTTPSConnection("apigw1.bot.or.th")
conn5e = http.client.HTTPSConnection("apigw1.bot.or.th")
conn7e = http.client.HTTPSConnection("apigw1.bot.or.th")
conn9e = http.client.HTTPSConnection("apigw1.bot.or.th")
conn11e = http.client.HTTPSConnection("apigw1.bot.or.th")

# ______________________________________________________________

headers = { 'X-IBM-Client-Id': "d9aeee4a-dc4b-4a91-a4c2-1c815493b58a" }

conn1u.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-01-01&end_period=2023-01-31&currency=USD", headers=headers)
conn3u.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-03-01&end_period=2023-03-31&currency=USD", headers=headers)
conn5u.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-05-01&end_period=2023-05-31&currency=USD", headers=headers)
conn7u.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-07-01&end_period=2023-07-31&currency=USD", headers=headers)
conn9u.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-09-01&end_period=2023-09-30&currency=USD", headers=headers)
conn11u.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-11-01&end_period=2023-11-30&currency=USD", headers=headers)

conn1j.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-01-01&end_period=2023-01-31&currency=JPY", headers=headers)
conn3j.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-03-01&end_period=2023-03-31&currency=JPY", headers=headers)
conn5j.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-05-01&end_period=2023-05-31&currency=JPY", headers=headers)
conn7j.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-07-01&end_period=2023-07-31&currency=JPY", headers=headers)
conn9j.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-09-01&end_period=2023-09-30&currency=JPY", headers=headers)
conn11j.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-11-01&end_period=2023-11-30&currency=JPY", headers=headers)

conn1e.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-01-01&end_period=2023-01-31&currency=EUR", headers=headers)
conn3e.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-03-01&end_period=2023-03-31&currency=EUR", headers=headers)
conn5e.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-05-01&end_period=2023-05-31&currency=EUR", headers=headers)
conn7e.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-07-01&end_period=2023-07-31&currency=EUR", headers=headers)
conn9e.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-09-01&end_period=2023-09-30&currency=EUR", headers=headers)
conn11e.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-11-01&end_period=2023-11-30&currency=EUR", headers=headers)
# ______________________________________________________________

res1u = conn1u.getresponse()
res3u = conn3u.getresponse()
res5u = conn5u.getresponse()
res7u = conn7u.getresponse()
res9u = conn9u.getresponse()
res11u = conn11u.getresponse()

res1j = conn1j.getresponse()
res3j = conn3j.getresponse()
res5j = conn5j.getresponse()
res7j = conn7j.getresponse()
res9j = conn9j.getresponse()
res11j = conn11j.getresponse()

res1e = conn1e.getresponse()
res3e = conn3e.getresponse()
res5e = conn5e.getresponse()
res7e = conn7e.getresponse()
res9e = conn9e.getresponse()
res11e = conn11e.getresponse()
# ______________________________________________________________

data_m1u = res1u.read()
data_m3u = res3u.read()
data_m5u = res5u.read()
data_m7u = res7u.read()
data_m9u = res9u.read()
data_m11u = res11u.read()

data_m1j = res1j.read()
data_m3j = res3j.read()
data_m5j = res5j.read()
data_m7j = res7j.read()
data_m9j = res9j.read()
data_m11j = res11j.read()

data_m1e = res1e.read()
data_m3e = res3e.read()
data_m5e = res5e.read()
data_m7e = res7e.read()
data_m9e = res9e.read()
data_m11e = res11e.read()
# ______________________________________________________________

print(data_m1u.decode("utf-8"))
print(data_m3u.decode("utf-8"))
print(data_m5u.decode("utf-8"))
print(data_m7u.decode("utf-8"))
print(data_m9u.decode("utf-8"))
print(data_m11u.decode("utf-8"))

print(data_m1j.decode("utf-8"))
print(data_m3j.decode("utf-8"))
print(data_m5j.decode("utf-8"))
print(data_m7j.decode("utf-8"))
print(data_m9j.decode("utf-8"))
print(data_m11j.decode("utf-8"))

print(data_m1e.decode("utf-8"))
print(data_m3e.decode("utf-8"))
print(data_m5e.decode("utf-8"))
print(data_m7e.decode("utf-8"))
print(data_m9e.decode("utf-8"))
print(data_m11e.decode("utf-8"))
# Out:
# {"result":{"timestamp":"2024-08-26 21:01:02","api":"Daily Weighted-average Interbank Exchange Rate - THB / USD","data":{"data_header":{"report_name_eng":"Rates of Exchange of Commercial Banks in Bangkok Metropolis (2002-present)","report_name_th":"อัตราแลกเปลี่ยนเฉลี่ยของธนาคารพาณิชย์ในกรุงเทพมหานคร (2545-ปัจจุบัน)","report_uoq_name_eng":"(Unit: Baht / 1 Unit of Foreign Currency)","report_uoq_name_th":"(หน่วย: บาท ต่อ 1 หน่วยเงินตราต่างประเทศ)","report_source_of_data":[{"source_of_data_eng":"Bank of Thailand","source_of_data_th":"ธนาคารแห่งประเทศไทย"}],"report_remark":[{"report_remark_eng":"Since Nov 16, 2015 the data regarding Buying Transfer Rate of PKR has been changed to Buying Rate using Foreign Exchange Rates (THOMSON REUTERS) with Bangkok Market Crossing.","report_remark_th":"ตั้งแต่วันที่ 16 พ.ย. 2558 ข้อมูลในอัตราซื้อเงินโอนของสกุล PKR ได้เปลี่ยนเป็นอัตราซื้อที่ใช้อัตราในตลาดต่างประเทศ (ทอมสันรอยเตอร์) คำนวณผ่านอัตราซื้อขายเงินดอลลาร์ สรอ. ในตลาดกรุงเทพฯ"}],"last_updated":"2
# ...

# %%
# 2023 เดือนเลขคู่
import http.client

conn2u = http.client.HTTPSConnection("apigw1.bot.or.th")
conn4u = http.client.HTTPSConnection("apigw1.bot.or.th")
conn6u = http.client.HTTPSConnection("apigw1.bot.or.th")
conn8u = http.client.HTTPSConnection("apigw1.bot.or.th")
conn10u = http.client.HTTPSConnection("apigw1.bot.or.th")
conn12u = http.client.HTTPSConnection("apigw1.bot.or.th")

conn2j = http.client.HTTPSConnection("apigw1.bot.or.th")
conn4j = http.client.HTTPSConnection("apigw1.bot.or.th")
conn6j = http.client.HTTPSConnection("apigw1.bot.or.th")
conn8j = http.client.HTTPSConnection("apigw1.bot.or.th")
conn10j = http.client.HTTPSConnection("apigw1.bot.or.th")
conn12j = http.client.HTTPSConnection("apigw1.bot.or.th")

conn2e = http.client.HTTPSConnection("apigw1.bot.or.th")
conn4e = http.client.HTTPSConnection("apigw1.bot.or.th")
conn6e = http.client.HTTPSConnection("apigw1.bot.or.th")
conn8e = http.client.HTTPSConnection("apigw1.bot.or.th")
conn10e = http.client.HTTPSConnection("apigw1.bot.or.th")
conn12e = http.client.HTTPSConnection("apigw1.bot.or.th")

# ______________________________________________________________

headers = { 'X-IBM-Client-Id': "d9aeee4a-dc4b-4a91-a4c2-1c815493b58a" }

conn2u.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-02-01&end_period=2023-02-28&currency=USD", headers=headers)
conn4u.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-04-01&end_period=2023-04-30&currency=USD", headers=headers)
conn6u.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-06-01&end_period=2023-06-30&currency=USD", headers=headers)
conn8u.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-08-01&end_period=2023-08-31&currency=USD", headers=headers)
conn10u.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-10-01&end_period=2023-10-31&currency=USD", headers=headers)
conn12u.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-12-01&end_period=2023-12-31&currency=USD", headers=headers)

conn2j.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-02-01&end_period=2023-02-28&currency=JPY", headers=headers)
conn4j.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-04-01&end_period=2023-04-30&currency=JPY", headers=headers)
conn6j.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-06-01&end_period=2023-06-30&currency=JPY", headers=headers)
conn8j.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-08-01&end_period=2023-08-31&currency=JPY", headers=headers)
conn10j.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-10-01&end_period=2023-10-31&currency=JPY", headers=headers)
conn12j.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-12-01&end_period=2023-12-31&currency=JPY", headers=headers)

conn2e.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-02-01&end_period=2023-02-28&currency=EUR", headers=headers)
conn4e.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-04-01&end_period=2023-04-30&currency=EUR", headers=headers)
conn6e.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-06-01&end_period=2023-06-30&currency=EUR", headers=headers)
conn8e.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-08-01&end_period=2023-08-31&currency=EUR", headers=headers)
conn10e.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-10-01&end_period=2023-10-31&currency=EUR", headers=headers)
conn12e.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2023-12-01&end_period=2023-12-31&currency=EUR", headers=headers)
# ______________________________________________________________

res2u = conn2u.getresponse()
res4u = conn4u.getresponse()
res6u = conn6u.getresponse()
res8u = conn8u.getresponse()
res10u = conn10u.getresponse()
res12u = conn12u.getresponse()

res2j = conn2j.getresponse()
res4j = conn4j.getresponse()
res6j = conn6j.getresponse()
res8j = conn8j.getresponse()
res10j = conn10j.getresponse()
res12j = conn12j.getresponse()

res2e = conn2e.getresponse()
res4e = conn4e.getresponse()
res6e = conn6e.getresponse()
res8e = conn8e.getresponse()
res10e = conn10e.getresponse()
res12e = conn12e.getresponse()
# ______________________________________________________________

data_m2u = res2u.read()
data_m4u = res4u.read()
data_m6u = res6u.read()
data_m8u = res8u.read()
data_m10u = res10u.read()
data_m12u = res12u.read()

data_m2j = res2j.read()
data_m4j = res4j.read()
data_m6j = res6j.read()
data_m8j = res8j.read()
data_m10j = res10j.read()
data_m12j = res12j.read()

data_m2e = res2e.read()
data_m4e = res4e.read()
data_m6e = res6e.read()
data_m8e = res8e.read()
data_m10e = res10e.read()
data_m12e = res12e.read()
# ______________________________________________________________

print(data_m2u.decode("utf-8"))
print(data_m4u.decode("utf-8"))
print(data_m6u.decode("utf-8"))
print(data_m8u.decode("utf-8"))
print(data_m10u.decode("utf-8"))
print(data_m12u.decode("utf-8"))

print(data_m2j.decode("utf-8"))
print(data_m4j.decode("utf-8"))
print(data_m6j.decode("utf-8"))
print(data_m8j.decode("utf-8"))
print(data_m10j.decode("utf-8"))
print(data_m12j.decode("utf-8"))

print(data_m2e.decode("utf-8"))
print(data_m4e.decode("utf-8"))
print(data_m6e.decode("utf-8"))
print(data_m8e.decode("utf-8"))
print(data_m10e.decode("utf-8"))
print(data_m12e.decode("utf-8"))
# Out:
# {"result":{"timestamp":"2024-08-26 21:01:12","api":"Daily Weighted-average Interbank Exchange Rate - THB / USD","data":{"data_header":{"report_name_eng":"Rates of Exchange of Commercial Banks in Bangkok Metropolis (2002-present)","report_name_th":"อัตราแลกเปลี่ยนเฉลี่ยของธนาคารพาณิชย์ในกรุงเทพมหานคร (2545-ปัจจุบัน)","report_uoq_name_eng":"(Unit: Baht / 1 Unit of Foreign Currency)","report_uoq_name_th":"(หน่วย: บาท ต่อ 1 หน่วยเงินตราต่างประเทศ)","report_source_of_data":[{"source_of_data_eng":"Bank of Thailand","source_of_data_th":"ธนาคารแห่งประเทศไทย"}],"report_remark":[{"report_remark_eng":"Since Nov 16, 2015 the data regarding Buying Transfer Rate of PKR has been changed to Buying Rate using Foreign Exchange Rates (THOMSON REUTERS) with Bangkok Market Crossing.","report_remark_th":"ตั้งแต่วันที่ 16 พ.ย. 2558 ข้อมูลในอัตราซื้อเงินโอนของสกุล PKR ได้เปลี่ยนเป็นอัตราซื้อที่ใช้อัตราในตลาดต่างประเทศ (ทอมสันรอยเตอร์) คำนวณผ่านอัตราซื้อขายเงินดอลลาร์ สรอ. ในตลาดกรุงเทพฯ"}],"last_updated":"2
# ...

# %%
# 2022 เดือนเลขคี่
import http.client

conn1u_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn3u_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn5u_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn7u_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn9u_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn11u_22 = http.client.HTTPSConnection("apigw1.bot.or.th")

conn1j_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn3j_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn5j_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn7j_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn9j_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn11j_22 = http.client.HTTPSConnection("apigw1.bot.or.th")

conn1e_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn3e_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn5e_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn7e_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn9e_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn11e_22 = http.client.HTTPSConnection("apigw1.bot.or.th")

# ______________________________________________________________

headers = { 'X-IBM-Client-Id': "d9aeee4a-dc4b-4a91-a4c2-1c815493b58a" }

conn1u_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-01-01&end_period=2022-01-31&currency=USD", headers=headers)
conn3u_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-03-01&end_period=2022-03-31&currency=USD", headers=headers)
conn5u_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-05-01&end_period=2022-05-31&currency=USD", headers=headers)
conn7u_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-07-01&end_period=2022-07-31&currency=USD", headers=headers)
conn9u_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-09-01&end_period=2022-09-30&currency=USD", headers=headers)
conn11u_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-11-01&end_period=2022-11-30&currency=USD", headers=headers)

conn1j_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-01-01&end_period=2022-01-31&currency=JPY", headers=headers)
conn3j_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-03-01&end_period=2022-03-31&currency=JPY", headers=headers)
conn5j_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-05-01&end_period=2022-05-31&currency=JPY", headers=headers)
conn7j_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-07-01&end_period=2022-07-31&currency=JPY", headers=headers)
conn9j_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-09-01&end_period=2022-09-30&currency=JPY", headers=headers)
conn11j_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-11-01&end_period=2022-11-30&currency=JPY", headers=headers)

conn1e_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-01-01&end_period=2022-01-31&currency=EUR", headers=headers)
conn3e_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-03-01&end_period=2022-03-31&currency=EUR", headers=headers)
conn5e_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-05-01&end_period=2022-05-31&currency=EUR", headers=headers)
conn7e_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-07-01&end_period=2022-07-31&currency=EUR", headers=headers)
conn9e_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-09-01&end_period=2022-09-30&currency=EUR", headers=headers)
conn11e_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-11-01&end_period=2022-11-30&currency=EUR", headers=headers)
# ______________________________________________________________

res1u_22 = conn1u_22.getresponse()
res3u_22 = conn3u_22.getresponse()
res5u_22 = conn5u_22.getresponse()
res7u_22 = conn7u_22.getresponse()
res9u_22 = conn9u_22.getresponse()
res11u_22 = conn11u_22.getresponse()

res1j_22 = conn1j_22.getresponse()
res3j_22 = conn3j_22.getresponse()
res5j_22 = conn5j_22.getresponse()
res7j_22 = conn7j_22.getresponse()
res9j_22 = conn9j_22.getresponse()
res11j_22 = conn11j_22.getresponse()

res1e_22 = conn1e_22.getresponse()
res3e_22 = conn3e_22.getresponse()
res5e_22 = conn5e_22.getresponse()
res7e_22 = conn7e_22.getresponse()
res9e_22 = conn9e_22.getresponse()
res11e_22 = conn11e_22.getresponse()
# ______________________________________________________________

data_m1u_22 = res1u_22.read()
data_m3u_22 = res3u_22.read()
data_m5u_22 = res5u_22.read()
data_m7u_22 = res7u_22.read()
data_m9u_22 = res9u_22.read()
data_m11u_22 = res11u_22.read()

data_m1j_22 = res1j_22.read()
data_m3j_22 = res3j_22.read()
data_m5j_22 = res5j_22.read()
data_m7j_22 = res7j_22.read()
data_m9j_22 = res9j_22.read()
data_m11j_22 = res11j_22.read()

data_m1e_22 = res1e_22.read()
data_m3e_22 = res3e_22.read()
data_m5e_22 = res5e_22.read()
data_m7e_22 = res7e_22.read()
data_m9e_22 = res9e_22.read()
data_m11e_22 = res11e_22.read()
# ______________________________________________________________

print(data_m1u_22.decode("utf-8"))
print(data_m3u_22.decode("utf-8"))
print(data_m5u_22.decode("utf-8"))
print(data_m7u_22.decode("utf-8"))
print(data_m9u_22.decode("utf-8"))
print(data_m11u_22.decode("utf-8"))

print(data_m1j_22.decode("utf-8"))
print(data_m3j_22.decode("utf-8"))
print(data_m5j_22.decode("utf-8"))
print(data_m7j_22.decode("utf-8"))
print(data_m9j_22.decode("utf-8"))
print(data_m11j_22.decode("utf-8"))

print(data_m1e_22.decode("utf-8"))
print(data_m3e_22.decode("utf-8"))
print(data_m5e_22.decode("utf-8"))
print(data_m7e_22.decode("utf-8"))
print(data_m9e_22.decode("utf-8"))
print(data_m11e_22.decode("utf-8"))
# Out:
# {"result":{"timestamp":"2024-08-26 21:01:23","api":"Daily Weighted-average Interbank Exchange Rate - THB / USD","data":{"data_header":{"report_name_eng":"Rates of Exchange of Commercial Banks in Bangkok Metropolis (2002-present)","report_name_th":"อัตราแลกเปลี่ยนเฉลี่ยของธนาคารพาณิชย์ในกรุงเทพมหานคร (2545-ปัจจุบัน)","report_uoq_name_eng":"(Unit: Baht / 1 Unit of Foreign Currency)","report_uoq_name_th":"(หน่วย: บาท ต่อ 1 หน่วยเงินตราต่างประเทศ)","report_source_of_data":[{"source_of_data_eng":"Bank of Thailand","source_of_data_th":"ธนาคารแห่งประเทศไทย"}],"report_remark":[{"report_remark_eng":"Since Nov 16, 2015 the data regarding Buying Transfer Rate of PKR has been changed to Buying Rate using Foreign Exchange Rates (THOMSON REUTERS) with Bangkok Market Crossing.","report_remark_th":"ตั้งแต่วันที่ 16 พ.ย. 2558 ข้อมูลในอัตราซื้อเงินโอนของสกุล PKR ได้เปลี่ยนเป็นอัตราซื้อที่ใช้อัตราในตลาดต่างประเทศ (ทอมสันรอยเตอร์) คำนวณผ่านอัตราซื้อขายเงินดอลลาร์ สรอ. ในตลาดกรุงเทพฯ"}],"last_updated":"2
# ...

# %%
# 2022 เดือนเลขคู่
import http.client

conn2u_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn4u_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn6u_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn8u_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn10u_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn12u_22 = http.client.HTTPSConnection("apigw1.bot.or.th")

conn2j_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn4j_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn6j_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn8j_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn10j_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn12j_22 = http.client.HTTPSConnection("apigw1.bot.or.th")

conn2e_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn4e_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn6e_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn8e_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn10e_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn12e_22 = http.client.HTTPSConnection("apigw1.bot.or.th")

# ______________________________________________________________

headers_22 = { 'X-IBM-Client-Id': "d9aeee4a-dc4b-4a91-a4c2-1c815493b58a" }

conn2u_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-02-01&end_period=2022-02-28&currency=USD", headers=headers)
conn4u_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-04-01&end_period=2022-04-30&currency=USD", headers=headers)
conn6u_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-06-01&end_period=2022-06-30&currency=USD", headers=headers)
conn8u_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-08-01&end_period=2022-08-31&currency=USD", headers=headers)
conn10u_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-10-01&end_period=2022-10-31&currency=USD", headers=headers)
conn12u_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-12-01&end_period=2022-12-31&currency=USD", headers=headers)

conn2j_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-02-01&end_period=2022-02-28&currency=JPY", headers=headers)
conn4j_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-04-01&end_period=2022-04-30&currency=JPY", headers=headers)
conn6j_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-06-01&end_period=2022-06-30&currency=JPY", headers=headers)
conn8j_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-08-01&end_period=2022-08-31&currency=JPY", headers=headers)
conn10j_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-10-01&end_period=2022-10-31&currency=JPY", headers=headers)
conn12j_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-12-01&end_period=2022-12-31&currency=JPY", headers=headers)

conn2e_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-02-01&end_period=2022-02-28&currency=EUR", headers=headers)
conn4e_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-04-01&end_period=2022-04-30&currency=EUR", headers=headers)
conn6e_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-06-01&end_period=2022-06-30&currency=EUR", headers=headers)
conn8e_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-08-01&end_period=2022-08-31&currency=EUR", headers=headers)
conn10e_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-10-01&end_period=2022-10-31&currency=EUR", headers=headers)
conn12e_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/DAILY_AVG_EXG_RATE/?start_period=2022-12-01&end_period=2022-12-31&currency=EUR", headers=headers)
# ______________________________________________________________

res2u_22 = conn2u_22.getresponse()
res4u_22 = conn4u_22.getresponse()
res6u_22 = conn6u_22.getresponse()
res8u_22 = conn8u_22.getresponse()
res10u_22 = conn10u_22.getresponse()
res12u_22 = conn12u_22.getresponse()

res2j_22 = conn2j_22.getresponse()
res4j_22 = conn4j_22.getresponse()
res6j_22 = conn6j_22.getresponse()
res8j_22 = conn8j_22.getresponse()
res10j_22 = conn10j_22.getresponse()
res12j_22 = conn12j_22.getresponse()

res2e_22 = conn2e_22.getresponse()
res4e_22 = conn4e_22.getresponse()
res6e_22 = conn6e_22.getresponse()
res8e_22 = conn8e_22.getresponse()
res10e_22 = conn10e_22.getresponse()
res12e_22 = conn12e_22.getresponse()
# ______________________________________________________________

data_m2u_22 = res2u_22.read()
data_m4u_22 = res4u_22.read()
data_m6u_22 = res6u_22.read()
data_m8u_22 = res8u_22.read()
data_m10u_22 = res10u_22.read()
data_m12u_22 = res12u_22.read()

data_m2j_22 = res2j_22.read()
data_m4j_22 = res4j_22.read()
data_m6j_22 = res6j_22.read()
data_m8j_22 = res8j_22.read()
data_m10j_22 = res10j_22.read()
data_m12j_22 = res12j_22.read()

data_m2e_22 = res2e_22.read()
data_m4e_22 = res4e_22.read()
data_m6e_22 = res6e_22.read()
data_m8e_22 = res8e_22.read()
data_m10e_22 = res10e_22.read()
data_m12e_22 = res12e_22.read()
# ______________________________________________________________

print(data_m2u_22.decode("utf-8"))
print(data_m4u_22.decode("utf-8"))
print(data_m6u_22.decode("utf-8"))
print(data_m8u_22.decode("utf-8"))
print(data_m10u_22.decode("utf-8"))
print(data_m12u_22.decode("utf-8"))

print(data_m2j_22.decode("utf-8"))
print(data_m4j_22.decode("utf-8"))
print(data_m6j_22.decode("utf-8"))
print(data_m8j_22.decode("utf-8"))
print(data_m10j_22.decode("utf-8"))
print(data_m12j_22.decode("utf-8"))

print(data_m2e_22.decode("utf-8"))
print(data_m4e_22.decode("utf-8"))
print(data_m6e_22.decode("utf-8"))
print(data_m8e_22.decode("utf-8"))
print(data_m10e_22.decode("utf-8"))
print(data_m12e_22.decode("utf-8"))
# Out:
# {"result":{"timestamp":"2024-08-26 21:01:32","api":"Daily Weighted-average Interbank Exchange Rate - THB / USD","data":{"data_header":{"report_name_eng":"Rates of Exchange of Commercial Banks in Bangkok Metropolis (2002-present)","report_name_th":"อัตราแลกเปลี่ยนเฉลี่ยของธนาคารพาณิชย์ในกรุงเทพมหานคร (2545-ปัจจุบัน)","report_uoq_name_eng":"(Unit: Baht / 1 Unit of Foreign Currency)","report_uoq_name_th":"(หน่วย: บาท ต่อ 1 หน่วยเงินตราต่างประเทศ)","report_source_of_data":[{"source_of_data_eng":"Bank of Thailand","source_of_data_th":"ธนาคารแห่งประเทศไทย"}],"report_remark":[{"report_remark_eng":"Since Nov 16, 2015 the data regarding Buying Transfer Rate of PKR has been changed to Buying Rate using Foreign Exchange Rates (THOMSON REUTERS) with Bangkok Market Crossing.","report_remark_th":"ตั้งแต่วันที่ 16 พ.ย. 2558 ข้อมูลในอัตราซื้อเงินโอนของสกุล PKR ได้เปลี่ยนเป็นอัตราซื้อที่ใช้อัตราในตลาดต่างประเทศ (ทอมสันรอยเตอร์) คำนวณผ่านอัตราซื้อขายเงินดอลลาร์ สรอ. ในตลาดกรุงเทพฯ"}],"last_updated":"2
# ...

# %% [markdown]
# แสดงอัตราแลกเปลี่ยนของรายวันของเดือนมกราคม มีนาคม พฤษภาคม กรกฎาคม กันยายน พฤศจิกายนของปี
# 2023 ในรูปแบบของตาราง

# %%
# USD
# Janaury
obj_m1u = json.loads(data_m1u)
m1u = pd.DataFrame(obj_m1u["result"]['data']["data_detail"], columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m1u.sort_values("period",ascending=True,inplace=True)
m1u.set_index("period",inplace=True);m1u
# Out:
#            currency_id buying_sight buying_transfer     selling    mid_rate
# period
# 2023-01-03         USD   34.1392000      34.2359000  34.5626000  34.3993000
# 2023-01-04         USD   33.9739000      34.0888000  34.4344000  34.2616000
# 2023-01-05         USD   33.6297000      33.7269000  34.0462000  33.8866000
# 2023-01-06         USD   33.7483000      33.8479000  34.1677000  34.0078000
# 2023-01-09         USD   33.2717000      33.3707000  33.6980000  33.5344000
# 2023-01-10         USD   33.1920000      33.2858000  33.6053000  33.4456000
# 2023-01-11         USD   33.2551000      33.3554000  33.6839000  33.5197000
# 2023-01-12         USD   33.0927000      33.1899000  33.5137000  33.3518000
# 2023-01-13         USD   32.8580000      32.9621000  33.2912000  33.1267000
# 2023-01-16         USD   32.5803000      32.6736000  32.9959000  32.8348000
# 2023-01-17         USD   32.8338000      32.9297000  33.2547000  33.0922000
# ...

# %%
# JPY
# Janaury
obj_m1j = json.loads(data_m1j)
m1j = pd.DataFrame(obj_m1j["result"]['data']["data_detail"], columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m1j.sort_values("period",ascending=True,inplace=True)
m1j.set_index("period",inplace=True);m1j
# Out:
#            currency_id buying_sight buying_transfer     selling    mid_rate
# period
# 2023-01-03         JPY   25.9944000      26.1043000  26.8448000  26.4746000
# 2023-01-04         JPY   25.7310000      25.8482000  26.5906000  26.2194000
# 2023-01-05         JPY   25.1989000      25.2996000  26.0316000  25.6656000
# 2023-01-06         JPY   24.9667000      25.0765000  25.8011000  25.4388000
# 2023-01-09         JPY   24.9896000      25.1029000  25.8457000  25.4743000
# 2023-01-10         JPY   24.9295000      25.0423000  25.7716000  25.4070000
# 2023-01-11         JPY   24.8759000      24.9845000  25.7104000  25.3475000
# 2023-01-12         JPY   24.8664000      24.9775000  25.7057000  25.3416000
# 2023-01-13         JPY   25.2446000      25.3564000  26.0943000  25.7254000
# 2023-01-16         JPY   25.2533000      25.3643000  26.1048000  25.7346000
# 2023-01-17         JPY   25.2357000      25.3458000  26.0862000  25.7160000
# ...

# %%
# ERU
# Janaury
obj_m1e = json.loads(data_m1e)
m1e = pd.DataFrame(obj_m1e["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m1e.sort_values("period",ascending=True,inplace=True)
m1e.set_index("period",inplace=True);m1e
# Out:
#            currency_id buying_sight buying_transfer     selling    mid_rate
# period
# 2023-01-03         EUR   36.1791000      36.2867000  37.0397000  36.6632000
# 2023-01-04         EUR   35.7064000      35.8216000  36.5698000  36.1957000
# 2023-01-05         EUR   35.4970000      35.6002000  36.3323000  35.9663000
# 2023-01-06         EUR   35.3213000      35.4278000  36.1566000  35.7922000
# 2023-01-09         EUR   35.2910000      35.3991000  36.1512000  35.7752000
# 2023-01-10         EUR   35.3980000      35.5064000  36.2519000  35.8792000
# 2023-01-11         EUR   35.4754000      35.5895000  36.3433000  35.9664000
# 2023-01-12         EUR   35.4011000      35.5124000  36.2662000  35.8893000
# 2023-01-13         EUR   35.4308000      35.5463000  36.2920000  35.9192000
# 2023-01-16         EUR   35.1456000      35.2537000  36.0049000  35.6293000
# 2023-01-17         EUR   35.3026000      35.4103000  36.1649000  35.7876000
# ...

# %%
# USD
# March
obj_m3u = json.loads(data_m3u)
m3u = pd.DataFrame(obj_m3u["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m3u.sort_values("period",ascending=True,inplace=True)
m3u.set_index("period",inplace=True);m3u
# Out:
#            currency_id buying_sight buying_transfer     selling    mid_rate
# period
# 2023-03-01         USD   34.8152000      34.9009000  35.2155000  35.0582000
# 2023-03-02         USD   34.5873000      34.6837000  35.0018000  34.8428000
# 2023-03-03         USD   34.5037000      34.6028000  34.9281000  34.7655000
# 2023-03-07         USD   34.2852000      34.3731000  34.6870000  34.5301000
# 2023-03-08         USD   34.8442000      34.9423000  35.2706000  35.1065000
# 2023-03-09         USD   34.8185000      34.9159000  35.2374000  35.0767000
# 2023-03-10         USD   34.7952000      34.8937000  35.2186000  35.0562000
# 2023-03-13         USD   34.3375000      34.4272000  34.7532000  34.5902000
# 2023-03-14         USD   34.2919000      34.3809000  34.7010000  34.5410000
# 2023-03-15         USD   34.2795000      34.3659000  34.6865000  34.5262000
# 2023-03-16         USD   34.2604000      34.3569000  34.6828000  34.5199000
# ...

# %%
# JPY
# March
obj_m3j = json.loads(data_m3j)
m3j = pd.DataFrame(obj_m3j["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m3j.sort_values("period",ascending=True,inplace=True)
m3j.set_index("period",inplace=True)
m3j
# Out:
#            currency_id buying_sight buying_transfer     selling    mid_rate
# period
# 2023-03-01         JPY   25.3048000      25.4017000  26.0879000  25.7448000
# 2023-03-02         JPY   25.0993000      25.2012000  25.9207000  25.5610000
# 2023-03-03         JPY   25.0021000      25.1109000  25.8348000  25.4729000
# 2023-03-07         JPY   24.9810000      25.0671000  25.7607000  25.4139000
# 2023-03-08         JPY   25.0773000      25.1870000  25.9065000  25.5468000
# 2023-03-09         JPY   25.1418000      25.2616000  25.9993000  25.6305000
# 2023-03-10         JPY   25.2783000      25.3913000  26.1195000  25.7554000
# 2023-03-13         JPY   25.3323000      25.4277000  26.1281000  25.7779000
# 2023-03-14         JPY   25.4222000      25.5209000  26.1920000  25.8565000
# 2023-03-15         JPY   25.2538000      25.3505000  26.0166000  25.6836000
# 2023-03-16         JPY   25.5055000      25.6188000  26.3184000  25.9686000
# ...

# %%
# ERU
# March
obj_m3e = json.loads(data_m3e)
m3e = pd.DataFrame(obj_m3e["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m3e.sort_values("period",ascending=True,inplace=True);m3e.set_index("period",inplace=True)
m3e
# Out:
#            currency_id buying_sight buying_transfer     selling    mid_rate
# period
# 2023-03-01         EUR   36.6791000      36.7746000  37.4886000  37.1316000
# 2023-03-02         EUR   36.6109000      36.7188000  37.4609000  37.0899000
# 2023-03-03         EUR   36.3823000      36.4953000  37.2536000  36.8745000
# 2023-03-07         EUR   36.4300000      36.5297000  37.2570000  36.8934000
# 2023-03-08         EUR   36.4996000      36.6100000  37.3637000  36.9869000
# 2023-03-09         EUR   36.4775000      36.5948000  37.3632000  36.9790000
# 2023-03-10         EUR   36.6155000      36.7294000  37.4892000  37.1093000
# 2023-03-13         EUR   36.5623000      36.6596000  37.3863000  37.0230000
# 2023-03-14         EUR   36.5175000      36.6205000  37.3173000  36.9689000
# 2023-03-15         EUR   36.6136000      36.7171000  37.4142000  37.0657000
# 2023-03-16         EUR   36.0833000      36.1932000  36.9232000  36.5582000
# ...

# %%
# USD
# May
obj_m5u = json.loads(data_m5u)
m5u = pd.DataFrame(obj_m5u["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m5u.sort_values("period",ascending=True,inplace=True)
m5u.set_index("period",inplace=True)
m5u
# Out:
#            currency_id buying_sight buying_transfer     selling    mid_rate
# period
# 2023-05-02         USD   33.9281000      34.0142000  34.3423000  34.1783000
# 2023-05-03         USD   33.7854000      33.8780000  34.2054000  34.0417000
# 2023-05-08         USD   33.6647000      33.7627000  34.0900000  33.9264000
# 2023-05-09         USD   33.4773000      33.5716000  33.9027000  33.7372000
# 2023-05-10         USD   33.4100000      33.5038000  33.8365000  33.6702000
# 2023-05-11         USD   33.4444000      33.5299000  33.8458000  33.6879000
# 2023-05-12         USD   33.6428000      33.7392000  34.0612000  33.9002000
# 2023-05-15         USD   33.5302000      33.6234000  33.9590000  33.7912000
# 2023-05-16         USD   33.6015000      33.6966000  34.0248000  33.8607000
# 2023-05-17         USD   33.9116000      34.0071000  34.3384000  34.1728000
# 2023-05-18         USD   33.9580000      34.0525000  34.3731000  34.2128000
# ...

# %%
# JPY
# May
obj_m5j = json.loads(data_m5j)
m5j = pd.DataFrame(obj_m5j["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m5j.sort_values("period",ascending=True,inplace=True)
m5j.set_index("period",inplace=True)
m5j
# Out:
#            currency_id buying_sight buying_transfer     selling    mid_rate
# period
# 2023-05-02         JPY   24.4524000      24.5488000  25.2290000  24.8889000
# 2023-05-03         JPY   24.5668000      24.6739000  25.3744000  25.0242000
# 2023-05-08         JPY   24.6975000      24.8072000  25.5268000  25.1670000
# 2023-05-09         JPY   24.5377000      24.6466000  25.3589000  25.0028000
# 2023-05-10         JPY   24.4486000      24.5620000  25.2814000  24.9217000
# 2023-05-11         JPY   24.6773000      24.7667000  25.4558000  25.1113000
# 2023-05-12         JPY   24.7333000      24.8444000  25.5654000  25.2049000
# 2023-05-15         JPY   24.4140000      24.5252000  25.2570000  24.8911000
# 2023-05-16         JPY   24.4502000      24.5617000  25.2779000  24.9198000
# 2023-05-17         JPY   24.5818000      24.6965000  25.4016000  25.0491000
# 2023-05-18         JPY   24.4321000      24.5476000  25.2599000  24.9038000
# ...

# %%
# EUR
# May
obj_m5e = json.loads(data_m5e)
m5e = pd.DataFrame(obj_m5e["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m5e.sort_values("period",ascending=True,inplace=True);m5e.set_index("period",inplace=True)
m5e
# Out:
#            currency_id buying_sight buying_transfer     selling    mid_rate
# period
# 2023-05-02         EUR   37.0800000      37.1827000  37.8819000  37.5323000
# 2023-05-03         EUR   37.0287000      37.1398000  37.8706000  37.5052000
# 2023-05-08         EUR   36.9296000      37.0395000  37.7903000  37.4149000
# 2023-05-09         EUR   36.5890000      36.6980000  37.4382000  37.0681000
# 2023-05-10         EUR   36.4264000      36.5402000  37.3058000  36.9230000
# 2023-05-11         EUR   36.4829000      36.5684000  37.2952000  36.9318000
# 2023-05-12         EUR   36.5244000      36.6343000  37.3834000  37.0089000
# 2023-05-15         EUR   36.2043000      36.3147000  37.0821000  36.6984000
# 2023-05-16         EUR   36.3211000      36.4322000  37.1888000  36.8105000
# 2023-05-17         EUR   36.6150000      36.7289000  37.4857000  37.1073000
# 2023-05-18         EUR   36.5844000      36.6930000  37.4383000  37.0657000
# ...

# %%
# USD
# July
obj_m7u = json.loads(data_m7u)
m7u = pd.DataFrame(obj_m7u["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m7u.sort_values("period",ascending=True,inplace=True);m7u.set_index("period",inplace=True)
m7u
# Out:
#            currency_id buying_sight buying_transfer     selling    mid_rate
# period
# 2023-07-03         USD   34.9544000      35.0408000  35.3599000  35.2004000
# 2023-07-04         USD   34.7521000      34.8508000  35.1751000  35.0130000
# 2023-07-05         USD   34.6502000      34.7392000  35.0723000  34.9058000
# 2023-07-06         USD   34.8458000      34.9426000  35.2660000  35.1043000
# 2023-07-07         USD   34.9809000      35.0778000  35.4111000  35.2445000
# 2023-07-10         USD   34.8819000      34.9775000  35.3065000  35.1420000
# 2023-07-11         USD   34.6424000      34.7408000  35.0823000  34.9116000
# 2023-07-12         USD   34.5671000      34.6542000  34.9919000  34.8231000
# 2023-07-13         USD   34.3405000      34.4436000  34.7699000  34.6068000
# 2023-07-14         USD   34.3503000      34.4453000  34.7683000  34.6068000
# 2023-07-17         USD   34.4071000      34.4973000  34.8191000  34.6582000
# ...

# %%
# JPY
# July
obj_m7j = json.loads(data_m7j)
m7j = pd.DataFrame(obj_m7j["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m7j.sort_values("period",ascending=True,inplace=True);m7j.set_index("period",inplace=True)
m7j
# Out:
#            currency_id buying_sight buying_transfer     selling    mid_rate
# period
# 2023-07-03         JPY   23.9595000      24.0461000  24.6819000  24.3640000
# 2023-07-04         JPY   23.7791000      23.8858000  24.5518000  24.2188000
# 2023-07-05         JPY   23.7269000      23.8202000  24.5196000  24.1699000
# 2023-07-06         JPY   23.9151000      24.0224000  24.7333000  24.3779000
# 2023-07-07         JPY   24.0590000      24.1670000  24.8658000  24.5164000
# 2023-07-10         JPY   24.2067000      24.3127000  25.0015000  24.6571000
# 2023-07-11         JPY   24.3152000      24.4350000  25.1519000  24.7935000
# 2023-07-12         JPY   24.5013000      24.6116000  25.3249000  24.9683000
# 2023-07-13         JPY   24.5350000      24.6428000  25.3519000  24.9974000
# 2023-07-14         JPY   24.6841000      24.7993000  25.5165000  25.1579000
# 2023-07-17         JPY   24.5866000      24.6889000  25.3778000  25.0334000
# ...

# %%
# EUR
# July
obj_m7e = json.loads(data_m7e)
m7e = pd.DataFrame(obj_m7e["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m7e.sort_values("period",ascending=True,inplace=True);m7e.set_index("period",inplace=True)
m7e
# Out:
#            currency_id buying_sight buying_transfer     selling    mid_rate
# period
# 2023-07-03         EUR   37.9342000      38.0340000  38.7191000  38.3766000
# 2023-07-04         EUR   37.6813000      37.7884000  38.5060000  38.1472000
# 2023-07-05         EUR   37.4896000      37.5912000  38.3396000  37.9654000
# 2023-07-06         EUR   37.5869000      37.6929000  38.4436000  38.0683000
# 2023-07-07         EUR   37.8669000      37.9823000  38.7358000  38.3591000
# 2023-07-10         EUR   38.0084000      38.1191000  38.8626000  38.4909000
# 2023-07-11         EUR   37.9315000      38.0409000  38.8015000  38.4212000
# 2023-07-12         EUR   37.9060000      38.0119000  38.7543000  38.3831000
# 2023-07-13         EUR   38.0677000      38.1712000  38.9216000  38.5464000
# 2023-07-14         EUR   38.3571000      38.4651000  39.2200000  38.8426000
# 2023-07-17         EUR   38.4397000      38.5362000  39.2672000  38.9017000
# ...

# %%
# USD
# September
obj_m9u = json.loads(data_m9u)
m9u = pd.DataFrame(obj_m9u["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m9u.sort_values("period",ascending=True,inplace=True);m9u.set_index("period",inplace=True)
m9u
# Out:
#            currency_id buying_sight buying_transfer     selling    mid_rate
# period
# 2023-09-01         USD   34.7591000      34.8568000  35.1899000  35.0234000
# 2023-09-04         USD   34.8974000      34.9753000  35.2939000  35.1346000
# 2023-09-05         USD   35.1099000      35.1954000  35.5299000  35.3627000
# 2023-09-06         USD   35.2383000      35.3273000  35.6592000  35.4933000
# 2023-09-07         USD   35.3227000      35.4079000  35.7322000  35.5701000
# 2023-09-08         USD   35.3050000      35.3889000  35.7111000  35.5500000
# 2023-09-11         USD   35.2527000      35.3466000  35.6730000  35.5098000
# 2023-09-12         USD   35.2984000      35.3824000  35.7210000  35.5517000
# 2023-09-13         USD   35.4158000      35.5146000  35.8401000  35.6774000
# 2023-09-14         USD   35.4864000      35.5673000  35.8827000  35.7250000
# 2023-09-15         USD   35.5316000      35.6110000  35.9323000  35.7717000
# ...

# %%
# JPY
# September
obj_m9j = json.loads(data_m9j)
m9j = pd.DataFrame(obj_m9j["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m9j.sort_values("period",ascending=True,inplace=True);m9j.set_index("period",inplace=True)
m9j
# Out:
#            currency_id buying_sight buying_transfer     selling    mid_rate
# period
# 2023-09-01         JPY   23.6405000      23.7513000  24.4347000  24.0930000
# 2023-09-04         JPY   23.6409000      23.7258000  24.3760000  24.0509000
# 2023-09-05         JPY   23.6926000      23.7879000  24.4672000  24.1276000
# 2023-09-06         JPY   23.6401000      23.7403000  24.4313000  24.0858000
# 2023-09-07         JPY   23.7164000      23.7962000  24.4562000  24.1262000
# 2023-09-08         JPY   23.7627000      23.8507000  24.4775000  24.1641000
# 2023-09-11         JPY   23.8076000      23.9155000  24.5744000  24.2450000
# 2023-09-12         JPY   23.8376000      23.9269000  24.5883000  24.2576000
# 2023-09-13         JPY   23.7741000      23.8887000  24.5828000  24.2358000
# 2023-09-14         JPY   23.8735000      23.9613000  24.6237000  24.2925000
# 2023-09-15         JPY   23.8724000      23.9528000  24.5845000  24.2687000
# ...

# %%
# EUR
# September
obj_m9e = json.loads(data_m9e)
m9e = pd.DataFrame(obj_m9e["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m9e.sort_values("period",ascending=True,inplace=True);m9e.set_index("period",inplace=True)
m9e
# Out:
#            currency_id buying_sight buying_transfer     selling    mid_rate
# period
# 2023-09-01         EUR   37.4945000      37.6064000  38.3343000  37.9704000
# 2023-09-04         EUR   37.4555000      37.5435000  38.2440000  37.8938000
# 2023-09-05         EUR   37.6617000      37.7616000  38.4926000  38.1271000
# 2023-09-06         EUR   37.5857000      37.6938000  38.4444000  38.0691000
# 2023-09-07         EUR   37.6957000      37.7774000  38.4954000  38.1364000
# 2023-09-08         EUR   37.6497000      37.7391000  38.4327000  38.0859000
# 2023-09-11         EUR   37.6003000      37.7065000  38.4261000  38.0663000
# 2023-09-12         EUR   37.7192000      37.8220000  38.5394000  38.1807000
# 2023-09-13         EUR   37.8618000      37.9693000  38.7138000  38.3416000
# 2023-09-14         EUR   37.9157000      37.9999000  38.7141000  38.3570000
# 2023-09-15         EUR   37.6574000      37.7499000  38.4301000  38.0900000
# ...

# %%
# USD
# November
obj_m11u = json.loads(data_m11u)
m11u = pd.DataFrame(obj_m11u["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m11u.sort_values("period",ascending=True,inplace=True);m11u.set_index("period",inplace=True)
m11u
# Out:
#            currency_id buying_sight buying_transfer     selling    mid_rate
# period
# 2023-11-01         USD   35.9930000      36.0887000  36.4147000  36.2517000
# 2023-11-02         USD   35.7565000      35.8486000  36.1776000  36.0131000
# 2023-11-03         USD   35.5997000      35.6953000  36.0194000  35.8574000
# 2023-11-06         USD   35.2100000      35.3005000  35.6259000  35.4632000
# 2023-11-07         USD   35.2629000      35.3597000  35.6811000  35.5204000
# 2023-11-08         USD   35.2638000      35.3562000  35.6781000  35.5172000
# 2023-11-09         USD   35.2297000      35.3206000  35.6458000  35.4832000
# 2023-11-10         USD   35.5657000      35.6419000  35.9698000  35.8059000
# 2023-11-13         USD   35.7702000      35.8690000  36.1947000  36.0319000
# 2023-11-14         USD   35.8312000      35.9093000  36.2334000  36.0714000
# 2023-11-15         USD   35.2681000      35.3601000  35.6954000  35.5278000
# ...

# %%
# JPY
# November
obj_m11j = json.loads(data_m11j)
m11j = pd.DataFrame(obj_m11j["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m11j.sort_values("period",ascending=True,inplace=True);m11j.set_index("period",inplace=True)
m11j
# Out:
#            currency_id buying_sight buying_transfer     selling    mid_rate
# period
# 2023-11-01         JPY   23.5282000      23.6326000  24.3327000  23.9827000
# 2023-11-02         JPY   23.5161000      23.6216000  24.3147000  23.9682000
# 2023-11-03         JPY   23.4271000      23.5262000  24.2083000  23.8673000
# 2023-11-06         JPY   23.2899000      23.3888000  24.0647000  23.7268000
# 2023-11-07         JPY   23.2020000      23.3143000  24.0244000  23.6694000
# 2023-11-08         JPY   23.1642000      23.2646000  23.9510000  23.6078000
# 2023-11-09         JPY   23.0885000      23.1872000  23.8600000  23.5236000
# 2023-11-10         JPY   23.2850000      23.3650000  24.0069000  23.6860000
# 2023-11-13         JPY   23.3358000      23.4338000  24.1098000  23.7718000
# 2023-11-14         JPY   23.4010000      23.4828000  24.1262000  23.8045000
# 2023-11-15         JPY   23.1696000      23.2703000  23.9467000  23.6085000
# ...

# %%
# EUR
# November
obj_m11e = json.loads(data_m11e)
m11e = pd.DataFrame(obj_m11e["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m11e.sort_values("period",ascending=True,inplace=True);m11e.set_index("period",inplace=True)
m11e
# Out:
#            currency_id buying_sight buying_transfer     selling    mid_rate
# period
# 2023-11-01         EUR   37.8355000      37.9385000  38.6857000  38.3121000
# 2023-11-02         EUR   37.6706000      37.7774000  38.5259000  38.1517000
# 2023-11-03         EUR   37.6257000      37.7278000  38.4545000  38.0912000
# 2023-11-06         EUR   37.5717000      37.6747000  38.4052000  38.0400000
# 2023-11-07         EUR   37.5293000      37.6359000  38.4010000  38.0185000
# 2023-11-08         EUR   37.4921000      37.5877000  38.3189000  37.9533000
# 2023-11-09         EUR   37.5205000      37.6221000  38.3468000  37.9845000
# 2023-11-10         EUR   37.7747000      37.8628000  38.5590000  38.2109000
# 2023-11-13         EUR   38.0247000      38.1271000  38.8565000  38.4918000
# 2023-11-14         EUR   38.1613000      38.2506000  38.9475000  38.5991000
# 2023-11-15         EUR   38.1512000      38.2573000  38.9771000  38.6172000
# ...

# %%
# USD
# เดือนเลขคู่
obj_m2u = json.loads(data_m2u)
m2u = pd.DataFrame(obj_m2u["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m2u.sort_values("period",ascending=True,inplace=True)
m2u.set_index("period",inplace=True)

obj_m4u = json.loads(data_m4u)
m4u = pd.DataFrame(obj_m4u["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m4u.sort_values("period",ascending=True,inplace=True)
m4u.set_index("period",inplace=True)

obj_m6u = json.loads(data_m6u)
m6u = pd.DataFrame(obj_m6u["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m6u.sort_values("period",ascending=True,inplace=True)
m6u.set_index("period",inplace=True)

obj_m8u = json.loads(data_m8u)
m8u = pd.DataFrame(obj_m8u["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m8u.sort_values("period",ascending=True,inplace=True)
m8u.set_index("period",inplace=True)

obj_m10u = json.loads(data_m10u)
m10u = pd.DataFrame(obj_m10u["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m10u.sort_values("period",ascending=True,inplace=True)
m10u.set_index("period",inplace=True)

obj_m12u = json.loads(data_m12u)
m12u = pd.DataFrame(obj_m12u["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m12u.sort_values("period",ascending=True,inplace=True)
m12u.set_index("period",inplace=True)

# %%
# 2022-USD

obj_m1u_22 = json.loads(data_m1u_22)
m1u_22 = pd.DataFrame(obj_m1u_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m1u_22.sort_values("period",ascending=True,inplace=True)
m1u_22.set_index("period",inplace=True)

obj_m2u_22 = json.loads(data_m2u_22)
m2u_22 = pd.DataFrame(obj_m2u_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m2u_22.sort_values("period",ascending=True,inplace=True)
m2u_22.set_index("period",inplace=True)

obj_m3u_22 = json.loads(data_m3u_22)
m3u_22 = pd.DataFrame(obj_m3u_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m3u_22.sort_values("period",ascending=True,inplace=True)
m3u_22.set_index("period",inplace=True)

obj_m4u_22 = json.loads(data_m4u_22)
m4u_22 = pd.DataFrame(obj_m4u_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m4u_22.sort_values("period",ascending=True,inplace=True)
m4u_22.set_index("period",inplace=True)

obj_m5u_22 = json.loads(data_m5u_22)
m5u_22 = pd.DataFrame(obj_m5u_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m5u_22.sort_values("period",ascending=True,inplace=True)
m5u_22.set_index("period",inplace=True)

obj_m6u_22 = json.loads(data_m6u_22)
m6u_22 = pd.DataFrame(obj_m6u_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m6u_22.sort_values("period",ascending=True,inplace=True)
m6u_22.set_index("period",inplace=True)

obj_m7u_22 = json.loads(data_m7u_22)
m7u_22 = pd.DataFrame(obj_m7u_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m7u_22.sort_values("period",ascending=True,inplace=True)
m7u_22.set_index("period",inplace=True)

obj_m8u_22 = json.loads(data_m8u_22)
m8u_22 = pd.DataFrame(obj_m8u_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m8u_22.sort_values("period",ascending=True,inplace=True)
m8u_22.set_index("period",inplace=True)

obj_m9u_22 = json.loads(data_m9u_22)
m9u_22 = pd.DataFrame(obj_m9u_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m9u_22.sort_values("period",ascending=True,inplace=True)
m9u_22.set_index("period",inplace=True)

obj_m10u_22 = json.loads(data_m10u_22)
m10u_22 = pd.DataFrame(obj_m10u_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m10u_22.sort_values("period",ascending=True,inplace=True)
m10u_22.set_index("period",inplace=True)

obj_m11u_22 = json.loads(data_m11u_22)
m11u_22 = pd.DataFrame(obj_m11u_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m11u_22.sort_values("period",ascending=True,inplace=True)
m11u_22.set_index("period",inplace=True)

obj_m12u_22 = json.loads(data_m12u_22)
m12u_22 = pd.DataFrame(obj_m12u_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m12u_22.sort_values("period",ascending=True,inplace=True)
m12u_22.set_index("period",inplace=True)

# %%
# JPY
# เดือนเลขคู่
obj_m2j = json.loads(data_m2j)
m2j = pd.DataFrame(obj_m2j["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m2j.sort_values("period",ascending=True,inplace=True)
m2j.set_index("period",inplace=True)

obj_m4j = json.loads(data_m4j)
m4j = pd.DataFrame(obj_m4j["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m4j.sort_values("period",ascending=True,inplace=True)
m4j.set_index("period",inplace=True)

obj_m6j = json.loads(data_m6j)
m6j = pd.DataFrame(obj_m6j["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m6j.sort_values("period",ascending=True,inplace=True)
m6j.set_index("period",inplace=True)

obj_m8j = json.loads(data_m8j)
m8j = pd.DataFrame(obj_m8j["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m8j.sort_values("period",ascending=True,inplace=True)
m8j.set_index("period",inplace=True)

obj_m10j = json.loads(data_m10j)
m10j = pd.DataFrame(obj_m10j["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m10j.sort_values("period",ascending=True,inplace=True)
m10j.set_index("period",inplace=True)

obj_m12j = json.loads(data_m12j)
m12j = pd.DataFrame(obj_m12j["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m12j.sort_values("period",ascending=True,inplace=True)
m12j.set_index("period",inplace=True)

# %%
# 2022-JPY

obj_m1j_22 = json.loads(data_m1j_22)
m1j_22 = pd.DataFrame(obj_m1j_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m1j_22.sort_values("period",ascending=True,inplace=True)
m1j_22.set_index("period",inplace=True)

obj_m2j_22 = json.loads(data_m2j_22)
m2j_22 = pd.DataFrame(obj_m2j_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m2j_22.sort_values("period",ascending=True,inplace=True)
m2j_22.set_index("period",inplace=True)

obj_m3j_22 = json.loads(data_m3j_22)
m3j_22 = pd.DataFrame(obj_m3j_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m3j_22.sort_values("period",ascending=True,inplace=True)
m3j_22.set_index("period",inplace=True)

obj_m4j_22 = json.loads(data_m4j_22)
m4j_22 = pd.DataFrame(obj_m4j_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m4j_22.sort_values("period",ascending=True,inplace=True)
m4j_22.set_index("period",inplace=True)

obj_m5j_22 = json.loads(data_m5j_22)
m5j_22 = pd.DataFrame(obj_m5j_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m5j_22.sort_values("period",ascending=True,inplace=True)
m5j_22.set_index("period",inplace=True)

obj_m6j_22 = json.loads(data_m6j_22)
m6j_22 = pd.DataFrame(obj_m6j_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m6j_22.sort_values("period",ascending=True,inplace=True)
m6j_22.set_index("period",inplace=True)

obj_m7j_22 = json.loads(data_m7j_22)
m7j_22 = pd.DataFrame(obj_m7j_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m7j_22.sort_values("period",ascending=True,inplace=True)
m7j_22.set_index("period",inplace=True)

obj_m8j_22 = json.loads(data_m8j_22)
m8j_22 = pd.DataFrame(obj_m8j_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m8j_22.sort_values("period",ascending=True,inplace=True)
m8j_22.set_index("period",inplace=True)

obj_m9j_22 = json.loads(data_m9j_22)
m9j_22 = pd.DataFrame(obj_m9j_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m9j_22.sort_values("period",ascending=True,inplace=True)
m9j_22.set_index("period",inplace=True)

obj_m10j_22 = json.loads(data_m10j_22)
m10j_22 = pd.DataFrame(obj_m10j_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m10j_22.sort_values("period",ascending=True,inplace=True)
m10j_22.set_index("period",inplace=True)

obj_m11j_22 = json.loads(data_m11j_22)
m11j_22 = pd.DataFrame(obj_m11j_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m11j_22.sort_values("period",ascending=True,inplace=True)
m11j_22.set_index("period",inplace=True)

obj_m12j_22 = json.loads(data_m12j_22)
m12j_22 = pd.DataFrame(obj_m12j_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m12j_22.sort_values("period",ascending=True,inplace=True)
m12j_22.set_index("period",inplace=True)

# %%
# EUR
# เดือนเลขคู่
obj_m2e = json.loads(data_m2e)
m2e = pd.DataFrame(obj_m2e["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m2e.sort_values("period",ascending=True,inplace=True)
m2e.set_index("period",inplace=True)

obj_m4e = json.loads(data_m4e)
m4e = pd.DataFrame(obj_m4e["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m4e.sort_values("period",ascending=True,inplace=True)
m4e.set_index("period",inplace=True)

obj_m6e = json.loads(data_m6e)
m6e = pd.DataFrame(obj_m6e["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m6e.sort_values("period",ascending=True,inplace=True)
m6e.set_index("period",inplace=True)

obj_m8e = json.loads(data_m8e)
m8e = pd.DataFrame(obj_m8e["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m8e.sort_values("period",ascending=True,inplace=True)
m8e.set_index("period",inplace=True)

obj_m10e = json.loads(data_m10e)
m10e = pd.DataFrame(obj_m10e["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m10e.sort_values("period",ascending=True,inplace=True)
m10e.set_index("period",inplace=True)

obj_m12e = json.loads(data_m12e)
m12e = pd.DataFrame(obj_m12e["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m12e.sort_values("period",ascending=True,inplace=True)
m12e.set_index("period",inplace=True)

# %%
# 2022-EUR

obj_m1e_22 = json.loads(data_m1e_22)
m1e_22 = pd.DataFrame(obj_m1e_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m1e_22.sort_values("period",ascending=True,inplace=True)
m1e_22.set_index("period",inplace=True)

obj_m2e_22 = json.loads(data_m2e_22)
m2e_22 = pd.DataFrame(obj_m2e_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m2e_22.sort_values("period",ascending=True,inplace=True)
m2e_22.set_index("period",inplace=True)

obj_m3e_22 = json.loads(data_m3e_22)
m3e_22 = pd.DataFrame(obj_m3e_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m3e_22.sort_values("period",ascending=True,inplace=True)
m3e_22.set_index("period",inplace=True)

obj_m4e_22 = json.loads(data_m4e_22)
m4e_22 = pd.DataFrame(obj_m4e_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m4e_22.sort_values("period",ascending=True,inplace=True)
m4e_22.set_index("period",inplace=True)

obj_m5e_22 = json.loads(data_m5e_22)
m5e_22 = pd.DataFrame(obj_m5e_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m5e_22.sort_values("period",ascending=True,inplace=True)
m5e_22.set_index("period",inplace=True)

obj_m6e_22 = json.loads(data_m6e_22)
m6e_22 = pd.DataFrame(obj_m6e_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m6e_22.sort_values("period",ascending=True,inplace=True)
m6e_22.set_index("period",inplace=True)

obj_m7e_22 = json.loads(data_m7e_22)
m7e_22 = pd.DataFrame(obj_m7e_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m7e_22.sort_values("period",ascending=True,inplace=True)
m7e_22.set_index("period",inplace=True)

obj_m8e_22 = json.loads(data_m8e_22)
m8e_22 = pd.DataFrame(obj_m8e_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m8e_22.sort_values("period",ascending=True,inplace=True)
m8e_22.set_index("period",inplace=True)

obj_m9e_22 = json.loads(data_m9e_22)
m9e_22 = pd.DataFrame(obj_m9e_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m9e_22.sort_values("period",ascending=True,inplace=True)
m9e_22.set_index("period",inplace=True)

obj_m10e_22 = json.loads(data_m10e_22)
m10e_22 = pd.DataFrame(obj_m10e_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m10e_22.sort_values("period",ascending=True,inplace=True)
m10e_22.set_index("period",inplace=True)

obj_m11e_22 = json.loads(data_m11e_22)
m11e_22 = pd.DataFrame(obj_m11e_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m11e_22.sort_values("period",ascending=True,inplace=True)
m11e_22.set_index("period",inplace=True)

obj_m12e_22 = json.loads(data_m12e_22)
m12e_22 = pd.DataFrame(obj_m12e_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
m12e_22.sort_values("period",ascending=True,inplace=True)
m12e_22.set_index("period",inplace=True)

# %% [markdown]
# แสดงอัตราแลกเปลี่ยนที่มากที่สุดของแต่ละเดือนภายใต้สกุลเงินแต่ละสกุล (ทําการเปรียบเทียบแบบรายวันของแต่
# ละเดือน เพื่อหาอัตราแลกเปลี่ยนที่มากที่สุดของแต่ละเดือนภายใต้แต่ละสกุลเงิน)  สําหรับปี 2022 และ ปี 2023

# %%
# 2022-USD

print(m1u_22.loc[m1u_22["buying_transfer"] == max(m1u_22["buying_transfer"])]["buying_transfer"])
print(m2u_22.loc[m2u_22["buying_transfer"] == max(m2u_22["buying_transfer"])]["buying_transfer"])
print(m3u_22.loc[m3u_22["buying_transfer"] == max(m3u_22["buying_transfer"])]["buying_transfer"])
print(m4u_22.loc[m4u_22["buying_transfer"] == max(m4u_22["buying_transfer"])]["buying_transfer"])
print(m5u_22.loc[m5u_22["buying_transfer"] == max(m5u_22["buying_transfer"])]["buying_transfer"])
print(m6u_22.loc[m6u_22["buying_transfer"] == max(m6u_22["buying_transfer"])]["buying_transfer"])
print(m7u_22.loc[m7u_22["buying_transfer"] == max(m7u_22["buying_transfer"])]["buying_transfer"])
print(m8u_22.loc[m8u_22["buying_transfer"] == max(m8u_22["buying_transfer"])]["buying_transfer"])
print(m9u_22.loc[m9u_22["buying_transfer"] == max(m9u_22["buying_transfer"])]["buying_transfer"])
print(m10u_22.loc[m10u_22["buying_transfer"] == max(m10u_22["buying_transfer"])]["buying_transfer"])
print(m11u_22.loc[m11u_22["buying_transfer"] == max(m11u_22["buying_transfer"])]["buying_transfer"])
print(m12u_22.loc[m12u_22["buying_transfer"] == max(m12u_22["buying_transfer"])]["buying_transfer"])
# Out:
# period
# 2022-01-10    33.4927000
# Name: buying_transfer, dtype: object
# period
# 2022-02-01    33.0701000
# Name: buying_transfer, dtype: object
# period
# 2022-03-29    33.5625000
# Name: buying_transfer, dtype: object
# period
# 2022-04-28    34.2837000
# Name: buying_transfer, dtype: object
# period
# 2022-05-13    34.5613000
# Name: buying_transfer, dtype: object
# period
# 2022-06-24    35.3679000
# Name: buying_transfer, dtype: object
# period
# 2022-07-22    36.6703000
# Name: buying_transfer, dtype: object
# period
# 2022-08-31    36.3165000
# Name: buying_transfer, dtype: object
# period
# 2022-09-28    37.9548000
# Name: buying_transfer, dtype: object
# period
# 2022-10-21    38.1755000
# Name: buying_transfer, dtype: object
# period
# 2022-11-01    37.7538000
# Name: buying_transfer, dtype: object
# period
# 2022-12-07    34.9212000
# Name: buying_transfer, dtype: object

# %%
# 2023-USD

print(m1u.loc[m1u["buying_transfer"] == max(m1u["buying_transfer"])]["buying_transfer"])
print(m2u.loc[m2u["buying_transfer"] == max(m2u["buying_transfer"])]["buying_transfer"])
print(m3u.loc[m3u["buying_transfer"] == max(m3u["buying_transfer"])]["buying_transfer"])
print(m4u.loc[m4u["buying_transfer"] == max(m4u["buying_transfer"])]["buying_transfer"])
print(m5u.loc[m5u["buying_transfer"] == max(m5u["buying_transfer"])]["buying_transfer"])
print(m6u.loc[m6u["buying_transfer"] == max(m6u["buying_transfer"])]["buying_transfer"])
print(m7u.loc[m7u["buying_transfer"] == max(m7u["buying_transfer"])]["buying_transfer"])
print(m8u.loc[m8u["buying_transfer"] == max(m8u["buying_transfer"])]["buying_transfer"])
print(m9u.loc[m9u["buying_transfer"] == max(m9u["buying_transfer"])]["buying_transfer"])
print(m10u.loc[m10u["buying_transfer"] == max(m10u["buying_transfer"])]["buying_transfer"])
print(m11u.loc[m11u["buying_transfer"] == max(m11u["buying_transfer"])]["buying_transfer"])
print(m12u.loc[m12u["buying_transfer"] == max(m12u["buying_transfer"])]["buying_transfer"])
# Out:
# period
# 2023-01-03    34.2359000
# Name: buying_transfer, dtype: object
# period
# 2023-02-28    34.9875000
# Name: buying_transfer, dtype: object
# period
# 2023-03-08    34.9423000
# Name: buying_transfer, dtype: object
# period
# 2023-04-24    34.3011000
# Name: buying_transfer, dtype: object
# period
# 2023-05-29    34.6227000
# Name: buying_transfer, dtype: object
# period
# 2023-06-29    35.4692000
# Name: buying_transfer, dtype: object
# period
# 2023-07-07    35.0778000
# Name: buying_transfer, dtype: object
# period
# 2023-08-17    35.3627000
# Name: buying_transfer, dtype: object
# period
# 2023-09-28    36.5672000
# Name: buying_transfer, dtype: object
# period
# 2023-10-04    36.9848000
# Name: buying_transfer, dtype: object
# period
# 2023-11-01    36.0887000
# Name: buying_transfer, dtype: object
# period
# 2023-12-13    35.5746000
# Name: buying_transfer, dtype: object

# %%
# 2022-JPY

print(m1j_22.loc[m1j_22["buying_transfer"] == max(m1j_22["buying_transfer"])]["buying_transfer"])
print(m2j_22.loc[m2j_22["buying_transfer"] == max(m2j_22["buying_transfer"])]["buying_transfer"])
print(m3j_22.loc[m3j_22["buying_transfer"] == max(m3j_22["buying_transfer"])]["buying_transfer"])
print(m4j_22.loc[m4j_22["buying_transfer"] == max(m4j_22["buying_transfer"])]["buying_transfer"])
print(m5j_22.loc[m5j_22["buying_transfer"] == max(m5j_22["buying_transfer"])]["buying_transfer"])
print(m6j_22.loc[m6j_22["buying_transfer"] == max(m6j_22["buying_transfer"])]["buying_transfer"])
print(m7j_22.loc[m7j_22["buying_transfer"] == max(m7j_22["buying_transfer"])]["buying_transfer"])
print(m8j_22.loc[m8j_22["buying_transfer"] == max(m8j_22["buying_transfer"])]["buying_transfer"])
print(m9j_22.loc[m9j_22["buying_transfer"] == max(m9j_22["buying_transfer"])]["buying_transfer"])
print(m10j_22.loc[m10j_22["buying_transfer"] == max(m10j_22["buying_transfer"])]["buying_transfer"])
print(m11j_22.loc[m11j_22["buying_transfer"] == max(m11j_22["buying_transfer"])]["buying_transfer"])
print(m12j_22.loc[m12j_22["buying_transfer"] == max(m12j_22["buying_transfer"])]["buying_transfer"])
# Out:
# period
# 2022-01-14    28.8106000
# Name: buying_transfer, dtype: object
# period
# 2022-02-03    28.6348000
# Name: buying_transfer, dtype: object
# period
# 2022-03-08    28.3089000
# Name: buying_transfer, dtype: object
# period
# 2022-04-04    26.9714000
# Name: buying_transfer, dtype: object
# period
# 2022-05-27    26.6096000
# Name: buying_transfer, dtype: object
# period
# 2022-06-01    26.2616000
# Name: buying_transfer, dtype: object
# period
# 2022-07-25    26.5908000
# Name: buying_transfer, dtype: object
# period
# 2022-08-02    27.2656000
# Name: buying_transfer, dtype: object
# period
# 2022-09-29    26.0414000
# Name: buying_transfer, dtype: object
# period
# 2022-10-03    25.8978000
# Name: buying_transfer, dtype: object
# period
# 2022-11-24    25.5577000
# Name: buying_transfer, dtype: object
# period
# 2022-12-21    25.9753000
# Name: buying_transfer, dtype: object

# %%
# 2023-JPY

print(m1j.loc[m1j["buying_transfer"] == max(m1j["buying_transfer"])]["buying_transfer"])
print(m2j.loc[m2j["buying_transfer"] == max(m2j["buying_transfer"])]["buying_transfer"])
print(m3j.loc[m3j["buying_transfer"] == max(m3j["buying_transfer"])]["buying_transfer"])
print(m4j.loc[m4j["buying_transfer"] == max(m4j["buying_transfer"])]["buying_transfer"])
print(m5j.loc[m5j["buying_transfer"] == max(m5j["buying_transfer"])]["buying_transfer"])
print(m6j.loc[m6j["buying_transfer"] == max(m6j["buying_transfer"])]["buying_transfer"])
print(m7j.loc[m7j["buying_transfer"] == max(m7j["buying_transfer"])]["buying_transfer"])
print(m8j.loc[m8j["buying_transfer"] == max(m8j["buying_transfer"])]["buying_transfer"])
print(m9j.loc[m9j["buying_transfer"] == max(m9j["buying_transfer"])]["buying_transfer"])
print(m10j.loc[m10j["buying_transfer"] == max(m10j["buying_transfer"])]["buying_transfer"])
print(m11j.loc[m11j["buying_transfer"] == max(m11j["buying_transfer"])]["buying_transfer"])
print(m12j.loc[m12j["buying_transfer"] == max(m12j["buying_transfer"])]["buying_transfer"])
# Out:
# period
# 2023-01-03    26.1043000
# Name: buying_transfer, dtype: object
# period
# 2023-02-24    25.4895000
# Name: buying_transfer, dtype: object
# period
# 2023-03-28    25.8995000
# Name: buying_transfer, dtype: object
# period
# 2023-04-07    25.5589000
# Name: buying_transfer, dtype: object
# period
# 2023-05-12    24.8444000
# Name: buying_transfer, dtype: object
# period
# 2023-06-07    24.6260000
# Name: buying_transfer, dtype: object
# period
# 2023-07-14    24.7993000
# Name: buying_transfer, dtype: object
# period
# 2023-08-07    24.1629000
# Name: buying_transfer, dtype: object
# period
# 2023-09-28    24.2636000
# Name: buying_transfer, dtype: object
# period
# 2023-10-04    24.5955000
# Name: buying_transfer, dtype: object
# period
# 2023-11-01    23.6326000
# Name: buying_transfer, dtype: object
# period
# 2023-12-14    24.4199000
# Name: buying_transfer, dtype: object

# %%
# 2022-EUR

print(m1e_22.loc[m1e_22["buying_transfer"] == max(m1e_22["buying_transfer"])]["buying_transfer"])
print(m2e_22.loc[m2e_22["buying_transfer"] == max(m2e_22["buying_transfer"])]["buying_transfer"])
print(m3e_22.loc[m3e_22["buying_transfer"] == max(m3e_22["buying_transfer"])]["buying_transfer"])
print(m4e_22.loc[m4e_22["buying_transfer"] == max(m4e_22["buying_transfer"])]["buying_transfer"])
print(m5e_22.loc[m5e_22["buying_transfer"] == max(m5e_22["buying_transfer"])]["buying_transfer"])
print(m6e_22.loc[m6e_22["buying_transfer"] == max(m6e_22["buying_transfer"])]["buying_transfer"])
print(m7e_22.loc[m7e_22["buying_transfer"] == max(m7e_22["buying_transfer"])]["buying_transfer"])
print(m8e_22.loc[m8e_22["buying_transfer"] == max(m8e_22["buying_transfer"])]["buying_transfer"])
print(m9e_22.loc[m9e_22["buying_transfer"] == max(m9e_22["buying_transfer"])]["buying_transfer"])
print(m10e_22.loc[m10e_22["buying_transfer"] == max(m10e_22["buying_transfer"])]["buying_transfer"])
print(m11e_22.loc[m11e_22["buying_transfer"] == max(m11e_22["buying_transfer"])]["buying_transfer"])
print(m12e_22.loc[m12e_22["buying_transfer"] == max(m12e_22["buying_transfer"])]["buying_transfer"])
# Out:
# period
# 2022-01-10    37.8074000
# Name: buying_transfer, dtype: object
# period
# 2022-02-04    37.4620000
# Name: buying_transfer, dtype: object
# period
# 2022-03-31    36.8184000
# Name: buying_transfer, dtype: object
# period
# 2022-04-04    36.5971000
# Name: buying_transfer, dtype: object
# period
# 2022-05-27    36.3763000
# Name: buying_transfer, dtype: object
# period
# 2022-06-24    37.0398000
# Name: buying_transfer, dtype: object
# period
# 2022-07-22    37.1549000
# Name: buying_transfer, dtype: object
# period
# 2022-08-02    36.6733000
# Name: buying_transfer, dtype: object
# period
# 2022-09-30    36.8328000
# Name: buying_transfer, dtype: object
# period
# 2022-10-27    37.6429000
# Name: buying_transfer, dtype: object
# period
# 2022-11-01    37.2012000
# Name: buying_transfer, dtype: object
# period
# 2022-12-16    36.9119000
# Name: buying_transfer, dtype: object

# %%
# 2023-EUR

print(m1e.loc[m1e["buying_transfer"] == max(m1e["buying_transfer"])]["buying_transfer"])
print(m2e.loc[m2e["buying_transfer"] == max(m2e["buying_transfer"])]["buying_transfer"])
print(m3e.loc[m3e["buying_transfer"] == max(m3e["buying_transfer"])]["buying_transfer"])
print(m4e.loc[m4e["buying_transfer"] == max(m4e["buying_transfer"])]["buying_transfer"])
print(m5e.loc[m5e["buying_transfer"] == max(m5e["buying_transfer"])]["buying_transfer"])
print(m6e.loc[m6e["buying_transfer"] == max(m6e["buying_transfer"])]["buying_transfer"])
print(m7e.loc[m7e["buying_transfer"] == max(m7e["buying_transfer"])]["buying_transfer"])
print(m8e.loc[m8e["buying_transfer"] == max(m8e["buying_transfer"])]["buying_transfer"])
print(m9e.loc[m9e["buying_transfer"] == max(m9e["buying_transfer"])]["buying_transfer"])
print(m10e.loc[m10e["buying_transfer"] == max(m10e["buying_transfer"])]["buying_transfer"])
print(m11e.loc[m11e["buying_transfer"] == max(m11e["buying_transfer"])]["buying_transfer"])
print(m12e.loc[m12e["buying_transfer"] == max(m12e["buying_transfer"])]["buying_transfer"])
# Out:
# period
# 2023-01-03    36.2867000
# Name: buying_transfer, dtype: object
# period
# 2023-02-28    36.8441000
# Name: buying_transfer, dtype: object
# period
# 2023-03-23    36.8424000
# Name: buying_transfer, dtype: object
# period
# 2023-04-25    37.5712000
# Name: buying_transfer, dtype: object
# period
# 2023-05-02    37.1827000
# Name: buying_transfer, dtype: object
# period
# 2023-06-29    38.4744000
# Name: buying_transfer, dtype: object
# period
# 2023-07-17    38.5362000
# Name: buying_transfer, dtype: object
# period
# 2023-08-16    38.2688000
# Name: buying_transfer, dtype: object
# period
# 2023-09-29    38.3036000
# Name: buying_transfer, dtype: object
# period
# 2023-10-09    38.7505000
# Name: buying_transfer, dtype: object
# period
# 2023-11-24    38.2776000
# Name: buying_transfer, dtype: object
# period
# 2023-12-13    38.1836000
# Name: buying_transfer, dtype: object

# %% [markdown]
# หาอัตราแลกเปลี่ยนเฉลี่ยของแต่ละเดือนของทั้งสองปี(นําค่าแต่ละเดือนของปี 2022 และ 2023 มาคํานวณหาค่าเฉลี่ย) ของแต่ละสกุลเงิน

# %%
# 2023-USD
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 1 ปี 2023: {m1u["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 2 ปี 2023: {m2u["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 3 ปี 2023: {m3u["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 4 ปี 2023: {m4u["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 5 ปี 2023: {m5u["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 6 ปี 2023: {m6u["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 7 ปี 2023: {m7u["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 8 ปี 2023: {m8u["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 9 ปี 2023: {m9u["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 10 ปี 2023: {m10u["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 11 ปี 2023: {m11u["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 12 ปี 2023: {m12u["buying_transfer"].values.astype(float).mean()}")
# Out:
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 1 ปี 2023: 33.065933333333334
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 2 ปี 2023: 33.844919999999995
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 3 ปี 2023: 34.33907272727272
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 4 ปี 2023: 34.11577647058824
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 5 ปี 2023: 34.07925
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 6 ปี 2023: 34.74975714285714
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 7 ปี 2023: 34.465965
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 8 ปี 2023: 34.87426666666667
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 9 ปี 2023: 35.6713
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 10 ปี 2023: 36.354775000000004
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 11 ปี 2023: 35.301663636363635
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 12 ปี 2023: 34.81019444444444

# %%
# 2023-JPY
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 1 ปี 2023: {m1j["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 2 ปี 2023: {m2j["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 3 ปี 2023: {m3j["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 4 ปี 2023: {m4j["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 5 ปี 2023: {m5j["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 6 ปี 2023: {m6j["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 7 ปี 2023: {m7j["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 8 ปี 2023: {m8j["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 9 ปี 2023: {m9j["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 10 ปี 2023: {m10j["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 11 ปี 2023: {m11j["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 12 ปี 2023: {m12j["buying_transfer"].values.astype(float).mean()}")
# Out:
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 1 ปี 2023: 25.158695238095238
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 2 ปี 2023: 25.256565000000002
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 3 ปี 2023: 25.485840909090903
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 4 ปี 2023: 25.33190588235294
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 5 ปี 2023: 24.602040000000002
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 6 ปี 2023: 24.391714285714286
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 7 ปี 2023: 24.214570000000002
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 8 ปี 2023: 23.872190476190475
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 9 ปี 2023: 23.954
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 10 ปี 2023: 24.112525
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 11 ปี 2023: 23.35081363636363
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 12 ปี 2023: 23.979983333333333

# %%
# 2023-EUR
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 1 ปี 2023: {m1e["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 2 ปี 2023: {m2e["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 3 ปี 2023: {m3e["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 4 ปี 2023: {m4e["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 5 ปี 2023: {m5e["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 6 ปี 2023: {m6e["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 7 ปี 2023: {m7e["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 8 ปี 2023: {m8e["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 9 ปี 2023: {m9e["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 10 ปี 2023: {m10e["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 11 ปี 2023: {m11e["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 12 ปี 2023: {m12e["buying_transfer"].values.astype(float).mean()}")
# Out:
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 1 ปี 2023: 35.43347142857142
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 2 ปี 2023: 36.047665
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 3 ปี 2023: 36.57738636363637
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 4 ปี 2023: 37.16241176470589
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 5 ปี 2023: 36.78203500000001
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 6 ปี 2023: 37.47006666666666
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 7 ปี 2023: 37.918744999999994
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 8 ปี 2023: 37.85020952380953
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 9 ปี 2023: 37.91774761904762
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 10 ปี 2023: 38.19766
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 11 ปี 2023: 37.9425590909091
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 12 ปี 2023: 37.803650000000005

# %%
# 2022-USD
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 1 ปี 2022: {m1u_22["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 2 ปี 2022: {m2u_22["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 3 ปี 2022: {m3u_22["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 4 ปี 2022: {m4u_22["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 5 ปี 2022: {m5u_22["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 6 ปี 2022: {m6u_22["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 7 ปี 2022: {m7u_22["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 8 ปี 2022: {m8u_22["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 9 ปี 2022: {m9u_22["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 10 ปี 2022: {m10u_22["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 11 ปี 2022: {m11u_22["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 12 ปี 2022: {m12u_22["buying_transfer"].values.astype(float).mean()}")
# Out:
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 1 ปี 2022: 33.07434500000001
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 2 ปี 2022: 32.50834210526316
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 3 ปี 2022: 33.08170434782609
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 4 ปี 2022: 33.64992941176471
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 5 ปี 2022: 34.247031578947364
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 6 ปี 2022: 34.8031380952381
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 7 ปี 2022: 36.168366666666664
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 8 ปี 2022: 35.71177727272728
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 9 ปี 2022: 36.869068181818186
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 10 ปี 2022: 37.75676111111111
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 11 ปี 2022: 36.26412272727272
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน USD เดือน 12 ปี 2022: 34.628195

# %%
# 2022-JPY
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 1 ปี 2022: {m1j_22["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 2 ปี 2022: {m2j_22["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 3 ปี 2022: {m3j_22["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 4 ปี 2022: {m4j_22["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 5 ปี 2022: {m5j_22["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 6 ปี 2022: {m6j_22["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 7 ปี 2022: {m7j_22["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 8 ปี 2022: {m8j_22["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 9 ปี 2022: {m9j_22["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 10 ปี 2022: {m10j_22["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 11 ปี 2022: {m11j_22["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 12 ปี 2022: {m12j_22["buying_transfer"].values.astype(float).mean()}")
# Out:
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 1 ปี 2022: 28.591320000000003
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 2 ปี 2022: 28.0178052631579
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 3 ปี 2022: 27.722578260869568
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 4 ปี 2022: 26.42571764705882
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 5 ปี 2022: 26.397231578947366
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 6 ปี 2022: 25.754095238095232
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 7 ปี 2022: 26.20216111111111
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 8 ปี 2022: 26.208695454545463
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 9 ปี 2022: 25.56734090909091
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 10 ปี 2022: 25.478477777777773
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 11 ปี 2022: 25.2381
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน JPY เดือน 12 ปี 2022: 25.45556

# %%
# 2022-EUR
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 1 ปี 2022: {m1e_22["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 2 ปี 2022: {m2e_22["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 3 ปี 2022: {m3e_22["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 4 ปี 2022: {m4e_22["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 5 ปี 2022: {m5e_22["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 6 ปี 2022: {m6e_22["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 7 ปี 2022: {m7e_22["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 8 ปี 2022: {m8e_22["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 9 ปี 2022: {m9e_22["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 10 ปี 2022: {m10e_22["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 11 ปี 2022: {m11e_22["buying_transfer"].values.astype(float).mean()}")
print(f"ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 12 ปี 2022: {m12e_22["buying_transfer"].values.astype(float).mean()}")
# Out:
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 1 ปี 2022: 37.25548
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 2 ปี 2022: 36.659699999999994
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 3 ปี 2022: 36.25642608695652
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 4 ปี 2022: 36.19845294117648
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 5 ปี 2022: 36.0512947368421
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 6 ปี 2022: 36.56600952380953
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 7 ปี 2022: 36.68089444444444
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 8 ปี 2022: 35.91905909090909
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 9 ปี 2022: 36.301745454545454
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 10 ปี 2022: 36.96454444444444
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 11 ปี 2022: 36.72223181818182
# ค่าเฉลี่ยของอัตรแลกเปลี่ยนสกุลเงิน EUR เดือน 12 ปี 2022: 36.453965

# %% [markdown]
# นําอัตราแลกเปลี่ยนรายวันมาพิจารณาเป็นค่าเฉลี่ยในช่วง Q1-Q4 ของปี 2022 และ 2023 จากนั้นทําการแสดงค่า
# ความต่างของแต่ละ quarter โดยแยกแต่ละสกุลเงิน

# %%
# 2022

import http.client
headers = {
    'X-IBM-Client-Id': "d9aeee4a-dc4b-4a91-a4c2-1c815493b58a",
    'accept': "application/json"
    }

# USD
conn_uq1_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn_uq2_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn_uq3_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn_uq4_22 = http.client.HTTPSConnection("apigw1.bot.or.th")

conn_uq1_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/QUARTERLY_AVG_EXG_RATE/?start_period=2022-Q1&end_period=2022-Q1&currency=USD", headers=headers)
conn_uq2_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/QUARTERLY_AVG_EXG_RATE/?start_period=2022-Q2&end_period=2022-Q2&currency=USD", headers=headers)
conn_uq3_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/QUARTERLY_AVG_EXG_RATE/?start_period=2022-Q3&end_period=2022-Q3&currency=USD", headers=headers)
conn_uq4_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/QUARTERLY_AVG_EXG_RATE/?start_period=2022-Q4&end_period=2022-Q4&currency=USD", headers=headers)



res_uq1_22 = conn_uq1_22.getresponse()
res_uq2_22 = conn_uq2_22.getresponse()
res_uq3_22 = conn_uq3_22.getresponse()
res_uq4_22 = conn_uq4_22.getresponse()


data_uq1_22 = res_uq1_22.read()
data_uq2_22 = res_uq2_22.read()
data_uq3_22 = res_uq3_22.read()
data_uq4_22 = res_uq4_22.read()

print(data_uq1_22.decode("utf-8"))
print(data_uq2_22.decode("utf-8"))
print(data_uq3_22.decode("utf-8"))
print(data_uq4_22.decode("utf-8"))
# _______________________________________________________________________________________________________________________________________________

# JPY
conn_jq1_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn_jq2_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn_jq3_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn_jq4_22 = http.client.HTTPSConnection("apigw1.bot.or.th")

conn_jq1_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/QUARTERLY_AVG_EXG_RATE/?start_period=2022-Q1&end_period=2022-Q1&currency=JPY", headers=headers)
conn_jq2_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/QUARTERLY_AVG_EXG_RATE/?start_period=2022-Q2&end_period=2022-Q2&currency=JPY", headers=headers)
conn_jq3_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/QUARTERLY_AVG_EXG_RATE/?start_period=2022-Q3&end_period=2022-Q3&currency=JPY", headers=headers)
conn_jq4_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/QUARTERLY_AVG_EXG_RATE/?start_period=2022-Q4&end_period=2022-Q4&currency=JPY", headers=headers)



res_jq1_22 = conn_jq1_22.getresponse()
res_jq2_22 = conn_jq2_22.getresponse()
res_jq3_22 = conn_jq3_22.getresponse()
res_jq4_22 = conn_jq4_22.getresponse()


data_jq1_22 = res_jq1_22.read()
data_jq2_22 = res_jq2_22.read()
data_jq3_22 = res_jq3_22.read()
data_jq4_22 = res_jq4_22.read()

print(data_jq1_22.decode("utf-8"))
print(data_jq2_22.decode("utf-8"))
print(data_jq3_22.decode("utf-8"))
print(data_jq4_22.decode("utf-8"))
# _______________________________________________________________________________________________________________________________________________
# EUR
conn_eq1_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn_eq2_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn_eq3_22 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn_eq4_22 = http.client.HTTPSConnection("apigw1.bot.or.th")

conn_eq1_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/QUARTERLY_AVG_EXG_RATE/?start_period=2022-Q1&end_period=2022-Q1&currency=EUR", headers=headers)
conn_eq2_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/QUARTERLY_AVG_EXG_RATE/?start_period=2022-Q2&end_period=2022-Q2&currency=EUR", headers=headers)
conn_eq3_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/QUARTERLY_AVG_EXG_RATE/?start_period=2022-Q3&end_period=2022-Q3&currency=EUR", headers=headers)
conn_eq4_22.request("GET", "/bot/public/Stat-ExchangeRate/v2/QUARTERLY_AVG_EXG_RATE/?start_period=2022-Q4&end_period=2022-Q4&currency=EUR", headers=headers)



res_eq1_22 = conn_eq1_22.getresponse()
res_eq2_22 = conn_eq2_22.getresponse()
res_eq3_22 = conn_eq3_22.getresponse()
res_eq4_22 = conn_eq4_22.getresponse()


data_eq1_22 = res_eq1_22.read()
data_eq2_22 = res_eq2_22.read()
data_eq3_22 = res_eq3_22.read()
data_eq4_22 = res_eq4_22.read()

print(data_eq1_22.decode("utf-8"))
print(data_eq2_22.decode("utf-8"))
print(data_eq3_22.decode("utf-8"))
print(data_eq4_22.decode("utf-8"))
# _______________________________________________________________________________________________________________________________________________
# Out:
# {"result":{"timestamp":"2024-08-26 21:01:45","api":"Quarterly Average Exchange Rate - THB / Foreign Currency","data":{"data_header":{"report_name_eng":"Rates of Exchange of Commercial Banks in Bangkok Metropolis (2002-present)","report_name_th":"อัตราแลกเปลี่ยนเฉลี่ยของธนาคารพาณิชย์ในกรุงเทพมหานคร (2545-ปัจจุบัน)","report_uoq_name_eng":"(Unit: Baht / 1 Unit of Foreign Currency)","report_uoq_name_th":"(หน่วย: บาท ต่อ 1 หน่วยเงินตราต่างประเทศ)","report_source_of_data":[{"source_of_data_eng":"Bank of Thailand","source_of_data_th":"ธนาคารแห่งประเทศไทย"}],"report_remark":[{"report_remark_eng":"Since Nov 16, 2015 the data regarding Buying Transfer Rate of PKR has been changed to Buying Rate using Foreign Exchange Rates (THOMSON REUTERS) with Bangkok Market Crossing.","report_remark_th":"ตั้งแต่วันที่ 16 พ.ย. 2558 ข้อมูลในอัตราซื้อเงินโอนของสกุล PKR ได้เปลี่ยนเป็นอัตราซื้อที่ใช้อัตราในตลาดต่างประเทศ (ทอมสันรอยเตอร์) คำนวณผ่านอัตราซื้อขายเงินดอลลาร์ สรอ. ในตลาดกรุงเทพฯ"}],"last_updated":"202
# ...

# %%
# 2023

import http.client
headers = {
    'X-IBM-Client-Id': "d9aeee4a-dc4b-4a91-a4c2-1c815493b58a",
    'accept': "application/json"
    }

# USD
conn_uq1_23 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn_uq2_23 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn_uq3_23 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn_uq4_23 = http.client.HTTPSConnection("apigw1.bot.or.th")

conn_uq1_23.request("GET", "/bot/public/Stat-ExchangeRate/v2/QUARTERLY_AVG_EXG_RATE/?start_period=2023-Q1&end_period=2023-Q1&currency=USD", headers=headers)
conn_uq2_23.request("GET", "/bot/public/Stat-ExchangeRate/v2/QUARTERLY_AVG_EXG_RATE/?start_period=2023-Q2&end_period=2023-Q2&currency=USD", headers=headers)
conn_uq3_23.request("GET", "/bot/public/Stat-ExchangeRate/v2/QUARTERLY_AVG_EXG_RATE/?start_period=2023-Q3&end_period=2023-Q3&currency=USD", headers=headers)
conn_uq4_23.request("GET", "/bot/public/Stat-ExchangeRate/v2/QUARTERLY_AVG_EXG_RATE/?start_period=2023-Q4&end_period=2023-Q4&currency=USD", headers=headers)



res_uq1_23 = conn_uq1_23.getresponse()
res_uq2_23 = conn_uq2_23.getresponse()
res_uq3_23 = conn_uq3_23.getresponse()
res_uq4_23 = conn_uq4_23.getresponse()


data_uq1_23 = res_uq1_23.read()
data_uq2_23 = res_uq2_23.read()
data_uq3_23 = res_uq3_23.read()
data_uq4_23 = res_uq4_23.read()

print(data_uq1_23.decode("utf-8"))
print(data_uq2_23.decode("utf-8"))
print(data_uq3_23.decode("utf-8"))
print(data_uq4_23.decode("utf-8"))
# _______________________________________________________________________________________________________________________________________________


# JPY
conn_jq1_23 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn_jq2_23 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn_jq3_23 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn_jq4_23 = http.client.HTTPSConnection("apigw1.bot.or.th")

conn_jq1_23.request("GET", "/bot/public/Stat-ExchangeRate/v2/QUARTERLY_AVG_EXG_RATE/?start_period=2023-Q1&end_period=2023-Q1&currency=JPY", headers=headers)
conn_jq2_23.request("GET", "/bot/public/Stat-ExchangeRate/v2/QUARTERLY_AVG_EXG_RATE/?start_period=2023-Q2&end_period=2023-Q2&currency=JPY", headers=headers)
conn_jq3_23.request("GET", "/bot/public/Stat-ExchangeRate/v2/QUARTERLY_AVG_EXG_RATE/?start_period=2023-Q3&end_period=2023-Q3&currency=JPY", headers=headers)
conn_jq4_23.request("GET", "/bot/public/Stat-ExchangeRate/v2/QUARTERLY_AVG_EXG_RATE/?start_period=2023-Q4&end_period=2023-Q4&currency=JPY", headers=headers)



res_jq1_23 = conn_jq1_23.getresponse()
res_jq2_23 = conn_jq2_23.getresponse()
res_jq3_23 = conn_jq3_23.getresponse()
res_jq4_23 = conn_jq4_23.getresponse()


data_jq1_23 = res_jq1_23.read()
data_jq2_23 = res_jq2_23.read()
data_jq3_23 = res_jq3_23.read()
data_jq4_23 = res_jq4_23.read()

print(data_jq1_23.decode("utf-8"))
print(data_jq2_23.decode("utf-8"))
print(data_jq3_23.decode("utf-8"))
print(data_jq4_23.decode("utf-8"))
# _______________________________________________________________________________________________________________________________________________
# EUR
conn_eq1_23 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn_eq2_23 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn_eq3_23 = http.client.HTTPSConnection("apigw1.bot.or.th")
conn_eq4_23 = http.client.HTTPSConnection("apigw1.bot.or.th")

conn_eq1_23.request("GET", "/bot/public/Stat-ExchangeRate/v2/QUARTERLY_AVG_EXG_RATE/?start_period=2023-Q1&end_period=2023-Q1&currency=EUR", headers=headers)
conn_eq2_23.request("GET", "/bot/public/Stat-ExchangeRate/v2/QUARTERLY_AVG_EXG_RATE/?start_period=2023-Q2&end_period=2023-Q2&currency=EUR", headers=headers)
conn_eq3_23.request("GET", "/bot/public/Stat-ExchangeRate/v2/QUARTERLY_AVG_EXG_RATE/?start_period=2023-Q3&end_period=2023-Q3&currency=EUR", headers=headers)
conn_eq4_23.request("GET", "/bot/public/Stat-ExchangeRate/v2/QUARTERLY_AVG_EXG_RATE/?start_period=2023-Q4&end_period=2023-Q4&currency=EUR", headers=headers)



res_eq1_23 = conn_eq1_23.getresponse()
res_eq2_23 = conn_eq2_23.getresponse()
res_eq3_23 = conn_eq3_23.getresponse()
res_eq4_23 = conn_eq4_23.getresponse()


data_eq1_23 = res_eq1_23.read()
data_eq2_23 = res_eq2_23.read()
data_eq3_23 = res_eq3_23.read()
data_eq4_23 = res_eq4_23.read()

print(data_eq1_23.decode("utf-8"))
print(data_eq2_23.decode("utf-8"))
print(data_eq3_23.decode("utf-8"))
print(data_eq4_23.decode("utf-8"))
# _______________________________________________________________________________________________________________________________________________
# Out:
# {"result":{"timestamp":"2024-08-26 21:01:52","api":"Quarterly Average Exchange Rate - THB / Foreign Currency","data":{"data_header":{"report_name_eng":"Rates of Exchange of Commercial Banks in Bangkok Metropolis (2002-present)","report_name_th":"อัตราแลกเปลี่ยนเฉลี่ยของธนาคารพาณิชย์ในกรุงเทพมหานคร (2545-ปัจจุบัน)","report_uoq_name_eng":"(Unit: Baht / 1 Unit of Foreign Currency)","report_uoq_name_th":"(หน่วย: บาท ต่อ 1 หน่วยเงินตราต่างประเทศ)","report_source_of_data":[{"source_of_data_eng":"Bank of Thailand","source_of_data_th":"ธนาคารแห่งประเทศไทย"}],"report_remark":[{"report_remark_eng":"Since Nov 16, 2015 the data regarding Buying Transfer Rate of PKR has been changed to Buying Rate using Foreign Exchange Rates (THOMSON REUTERS) with Bangkok Market Crossing.","report_remark_th":"ตั้งแต่วันที่ 16 พ.ย. 2558 ข้อมูลในอัตราซื้อเงินโอนของสกุล PKR ได้เปลี่ยนเป็นอัตราซื้อที่ใช้อัตราในตลาดต่างประเทศ (ทอมสันรอยเตอร์) คำนวณผ่านอัตราซื้อขายเงินดอลลาร์ สรอ. ในตลาดกรุงเทพฯ"}],"last_updated":"202
# ...

# %%
# USD
# 2022
obj_uq1_22 = json.loads(data_uq1_22)
obj_uq2_22 = json.loads(data_uq2_22)
obj_uq3_22 = json.loads(data_uq3_22)
obj_uq4_22 = json.loads(data_uq4_22)

uq1_22 = pd.DataFrame(obj_uq1_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
uq2_22 = pd.DataFrame(obj_uq2_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
uq3_22 = pd.DataFrame(obj_uq3_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
uq4_22 = pd.DataFrame(obj_uq4_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])

uq1_22.set_index("period",inplace=True)
uq2_22.set_index("period",inplace=True)
uq3_22.set_index("period",inplace=True)
uq4_22.set_index("period",inplace=True)

u_22 = pd.merge(uq1_22,uq2_22,how="outer")
u_22 = pd.merge(u_22,uq3_22,how="outer")
u_22 = pd.merge(u_22,uq4_22,how="outer")
u_22
# Out:
#   currency_id buying_sight buying_transfer     selling    mid_rate
# 0         USD   32.7930000      32.8881000  33.2176000  33.0529000
# 1         USD   34.1364000      34.2333000  34.5606000  34.3970000
# 2         USD   36.1195000      36.2164000  36.5453000  36.3808000
# 3         USD   36.1530000      36.2498000  36.5795000  36.4147000

# %%
# JPY
# 2022
obj_jq1_22 = json.loads(data_jq1_22)
obj_jq2_22 = json.loads(data_jq2_22)
obj_jq3_22 = json.loads(data_jq3_22)
obj_jq4_22 = json.loads(data_jq4_22)

jq1_22 = pd.DataFrame(obj_jq1_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
jq2_22 = pd.DataFrame(obj_jq2_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
jq3_22 = pd.DataFrame(obj_jq3_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
jq4_22 = pd.DataFrame(obj_jq4_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])

jq1_22.set_index("period",inplace=True)
jq2_22.set_index("period",inplace=True)
jq3_22.set_index("period",inplace=True)
jq4_22.set_index("period",inplace=True)

j_22 = pd.merge(jq1_22,jq2_22,how="outer")
j_22 = pd.merge(j_22,jq3_22,how="outer")
j_22 = pd.merge(j_22,jq4_22,how="outer")
j_22
# Out:
#   currency_id buying_sight buying_transfer     selling    mid_rate
# 0         JPY   25.2876000      25.3907000  26.0954000  25.7431000
# 1         JPY   25.8898000      25.9927000  26.6943000  26.3435000
# 2         JPY   26.0891000      26.1923000  26.8907000  26.5415000
# 3         JPY   28.0085000      28.1106000  28.8382000  28.4744000

# %%
# EUR
# 2022
obj_eq1_22 = json.loads(data_eq1_22)
obj_eq2_22 = json.loads(data_eq2_22)
obj_eq3_22 = json.loads(data_eq3_22)
obj_eq4_22 = json.loads(data_eq4_22)

eq1_22 = pd.DataFrame(obj_eq1_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
eq2_22 = pd.DataFrame(obj_eq2_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
eq3_22 = pd.DataFrame(obj_eq3_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
eq4_22 = pd.DataFrame(obj_eq4_22["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])

eq1_22.set_index("period",inplace=True)
eq2_22.set_index("period",inplace=True)
eq3_22.set_index("period",inplace=True)
eq4_22.set_index("period",inplace=True)

e_22 = pd.merge(eq1_22,eq2_22,how="outer")
e_22 = pd.merge(e_22,eq3_22,how="outer")
e_22 = pd.merge(e_22,eq4_22,how="outer")
e_22
# Out:
#   currency_id buying_sight buying_transfer     selling    mid_rate
# 0         EUR   36.1577000      36.2719000  37.0056000  36.6388000
# 1         EUR   36.1905000      36.3006000  37.0453000  36.6730000
# 2         EUR   36.6045000      36.7136000  37.4580000  37.0858000
# 3         EUR   36.6133000      36.7239000  37.4661000  37.0950000

# %%
# USD
# 2023
obj_uq1_23 = json.loads(data_uq1_23)
obj_uq2_23 = json.loads(data_uq2_23)
obj_uq3_23 = json.loads(data_uq3_23)
obj_uq4_23 = json.loads(data_uq4_23)

uq1_23 = pd.DataFrame(obj_uq1_23["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
uq2_23 = pd.DataFrame(obj_uq2_23["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
uq3_23 = pd.DataFrame(obj_uq3_23["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
uq4_23 = pd.DataFrame(obj_uq4_23["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])

uq1_23.set_index("period",inplace=True)
uq2_23.set_index("period",inplace=True)
uq3_23.set_index("period",inplace=True)
uq4_23.set_index("period",inplace=True)

u_23 = pd.merge(uq1_23,uq2_23,how="outer")
u_23 = pd.merge(u_23,uq3_23,how="outer")
u_23 = pd.merge(u_23,uq4_23,how="outer")
u_23
# Out:
#   currency_id buying_sight buying_transfer     selling    mid_rate
# 0         USD   33.6545000      33.7500000  34.0743000  33.9122000
# 1         USD   34.2213000      34.3150000  34.6416000  34.4783000
# 2         USD   34.9133000      35.0039000  35.3303000  35.1671000
# 3         USD   35.3998000      35.4889000  35.8135000  35.6512000

# %%
# JPY
# 2023
obj_jq1_23 = json.loads(data_jq1_23)
obj_jq2_23 = json.loads(data_jq2_23)
obj_jq3_23 = json.loads(data_jq3_23)
obj_jq4_23 = json.loads(data_jq4_23)

jq1_23 = pd.DataFrame(obj_jq1_23["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
jq2_23 = pd.DataFrame(obj_jq2_23["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
jq3_23 = pd.DataFrame(obj_jq3_23["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
jq4_23 = pd.DataFrame(obj_jq4_23["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])

jq1_23.set_index("period",inplace=True)
jq2_23.set_index("period",inplace=True)
jq3_23.set_index("period",inplace=True)
jq4_23.set_index("period",inplace=True)

j_23 = pd.merge(jq1_23,jq2_23,how="outer")
j_23 = pd.merge(j_23,jq3_23,how="outer")
j_23 = pd.merge(j_23,jq4_23,how="outer")
j_23
# Out:
#   currency_id buying_sight buying_transfer     selling    mid_rate
# 0         JPY   23.7157000      23.8144000  24.4923000  24.1534000
# 1         JPY   23.9150000      24.0136000  24.6900000  24.3518000
# 2         JPY   24.6705000      24.7752000  25.4748000  25.1250000
# 3         JPY   25.1931000      25.3004000  26.0175000  25.6590000

# %%
# EUR
# 2023
obj_eq1_23 = json.loads(data_eq1_23)
obj_eq2_23 = json.loads(data_eq2_23)
obj_eq3_23 = json.loads(data_eq3_23)
obj_eq4_23 = json.loads(data_eq4_23)

eq1_23 = pd.DataFrame(obj_eq1_23["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
eq2_23 = pd.DataFrame(obj_eq2_23["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
eq3_23 = pd.DataFrame(obj_eq3_23["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])
eq4_23 = pd.DataFrame(obj_eq4_23["result"]['data']["data_detail"],columns=["period", "currency_id", "buying_sight", "buying_transfer", "selling", "mid_rate"])

eq1_23.set_index("period",inplace=True)
eq2_23.set_index("period",inplace=True)
eq3_23.set_index("period",inplace=True)
eq4_23.set_index("period",inplace=True)

e_23 = pd.merge(eq1_23,eq2_23,how="outer")
e_23 = pd.merge(e_23,eq3_23,how="outer")
e_23 = pd.merge(e_23,eq4_23,how="outer")
e_23
# Out:
#   currency_id buying_sight buying_transfer     selling    mid_rate
# 0         EUR   35.9107000      36.0195000  36.7568000  36.3882000
# 1         EUR   37.0301000      37.1382000  37.8761000  37.5072000
# 2         EUR   37.7933000      37.8955000  38.6195000  38.2575000
# 3         EUR   37.8817000      37.9813000  38.7030000  38.3422000

# %% [markdown]
# ให้ทําการคํานวณว่าถ้ามีเงิน 100 Dollars จะแลกเป็นเงินสกุลเยนได้เท่าไหร่ โดยพิจารณาเป็นอัตรารายเดือนของปี
# 2022 คํานวณเฉพาะค่า buy_transfer และ selling

# %%
# 2022-M1
columns_u = ["buying_sight", "mid_rate", "buying_transfer", "currency_id"]
columns_j = ["buying_sight", "mid_rate", "selling", "currency_id"]


oneh_m1u_22 = m1u_22.drop(columns_u, axis=1)

oneh_m1j_22 = m1j_22.drop(columns_j, axis=1)

oneh_m1_22 = pd.merge(oneh_m1u_22,oneh_m1j_22, how="inner", on="period")
oneh_m1_22["100 Dollars = JPY"] = ((oneh_m1_22["selling"].astype(float))*100)/(oneh_m1_22["buying_transfer"].astype(float))
oneh_m1_22
# Out:
#                selling buying_transfer  100 Dollars = JPY
# period
# 2022-01-04  33.4744000      28.4911000         117.490725
# 2022-01-05  33.3686000      28.2724000         118.025353
# 2022-01-06  33.5319000      28.4775000         117.748749
# 2022-01-07  33.7446000      28.6113000         117.941513
# 2022-01-10  33.8333000      28.7478000         117.690049
# 2022-01-11  33.6961000      28.7279000         117.293989
# 2022-01-12  33.5231000      28.5835000         117.281299
# 2022-01-13  33.4476000      28.6839000         116.607574
# 2022-01-14  33.3721000      28.8106000         115.832714
# 2022-01-17  33.4245000      28.7107000         116.418269
# 2022-01-18  33.1751000      28.4135000         116.758231
# 2022-01-19  33.3568000      28.6075000         116.601590
# 2022-01-20  33.0887000      28.4543000         116.287169
# 2022-01-21  33.1835000      28.6646000         115.764741
# 2022-01-24  33.1905000      28.6575000         115.817849
# ...

# %%
# 2022-M2
columns_u = ["buying_sight", "mid_rate", "buying_transfer", "currency_id"]
columns_j = ["buying_sight", "mid_rate", "selling", "currency_id"]


oneh_m2u_22 = m2u_22.drop(columns_u, axis=1)

oneh_m2j_22 = m2j_22.drop(columns_j, axis=1)

oneh_m2_22 = pd.merge(oneh_m2u_22,oneh_m2j_22, how="inner", on="period")
oneh_m2_22["100 Dollars = JPY"] = ((oneh_m2_22["selling"].astype(float))*100)/(oneh_m2_22["buying_transfer"].astype(float))
oneh_m2_22
# Out:
#                selling buying_transfer  100 Dollars = JPY
# period
# 2022-02-01  33.4062000      28.5304000         117.089841
# 2022-02-02  33.3648000      28.5981000         116.667891
# 2022-02-03  33.3382000      28.6348000         116.425468
# 2022-02-04  33.1956000      28.3979000         116.894559
# 2022-02-07  33.1084000      28.2335000         117.266368
# 2022-02-08  33.1364000      28.2267000         117.393815
# 2022-02-09  33.0478000      28.1317000         117.475304
# 2022-02-10  32.8860000      27.9743000         117.557901
# 2022-02-11  32.8774000      27.8454000         118.071207
# 2022-02-14  32.7589000      27.8949000         117.436879
# 2022-02-15  32.5224000      27.6928000         117.439912
# 2022-02-17  32.4063000      27.5925000         117.446045
# 2022-02-18  32.3059000      27.5700000         117.177729
# 2022-02-21  32.3034000      27.5982000         117.048938
# 2022-02-22  32.5484000      27.8834000         116.730384
# ...

# %%
# 2022-M3
columns_u = ["buying_sight", "mid_rate", "buying_transfer", "currency_id"]
columns_j = ["buying_sight", "mid_rate", "selling", "currency_id"]


oneh_m3u_22 = m3u_22.drop(columns_u, axis=1)

oneh_m3j_22 = m3j_22.drop(columns_j, axis=1)

oneh_m3_22 = pd.merge(oneh_m3u_22,oneh_m3j_22, how="inner", on="period")
oneh_m3_22["100 Dollars = JPY"] = ((oneh_m3_22["selling"].astype(float))*100)/(oneh_m3_22["buying_transfer"].astype(float))
oneh_m3_22
# Out:
#                selling buying_transfer  100 Dollars = JPY
# period
# 2022-03-01  32.7934000      27.9930000         117.148573
# 2022-03-02  32.8369000      28.0615000         117.017622
# 2022-03-03  32.6850000      27.7862000         117.630334
# 2022-03-04  32.7927000      27.9294000         117.412834
# 2022-03-07  33.0146000      28.2301000         116.948222
# 2022-03-08  33.2526000      28.3089000         117.463413
# 2022-03-09  33.3326000      28.2784000         117.873006
# 2022-03-10  33.2195000      28.1327000         118.081450
# 2022-03-11  33.3846000      28.1850000         118.448111
# 2022-03-14  33.5728000      28.0454000         119.708758
# 2022-03-15  33.6557000      27.9708000         120.324410
# 2022-03-16  33.6075000      27.9324000         120.317266
# 2022-03-17  33.4203000      27.6675000         120.792627
# 2022-03-18  33.4598000      27.7064000         120.765599
# 2022-03-21  33.5805000      27.6859000         121.290982
# ...

# %%
# 2022-M4
columns_u = ["buying_sight", "mid_rate", "buying_transfer", "currency_id"]
columns_j = ["buying_sight", "mid_rate", "selling", "currency_id"]


oneh_m4u_22 = m4u_22.drop(columns_u, axis=1)

oneh_m4j_22 = m4j_22.drop(columns_j, axis=1)

oneh_m4_22 = pd.merge(oneh_m4u_22,oneh_m4j_22, how="inner", on="period")
oneh_m4_22["100 Dollars = JPY"] = ((oneh_m4_22["selling"].astype(float))*100)/(oneh_m4_22["buying_transfer"].astype(float))
oneh_m4_22
# Out:
#                selling buying_transfer  100 Dollars = JPY
# period
# 2022-04-01  33.5272000      26.9382000         124.459689
# 2022-04-04  33.6439000      26.9714000         124.739168
# 2022-04-05  33.6219000      26.9601000         124.709849
# 2022-04-07  33.6611000      26.7461000         125.854237
# 2022-04-08  33.7248000      26.7494000         126.076847
# 2022-04-11  33.7728000      26.5870000         127.027495
# 2022-04-12  33.8338000      26.5046000         127.652558
# 2022-04-18  33.8340000      26.2687000         128.799674
# 2022-04-19  33.8862000      26.0766000         129.948690
# 2022-04-20  33.9838000      25.9174000         131.123492
# 2022-04-21  33.9836000      26.0299000         130.556014
# 2022-04-22  34.0791000      26.0916000         130.613301
# 2022-04-25  34.1637000      26.1355000         130.717606
# 2022-04-26  34.2930000      26.3779000         130.006559
# 2022-04-27  34.4934000      26.5835000         129.754923
# ...

# %%
# 2022-M5
columns_u = ["buying_sight", "mid_rate", "buying_transfer", "currency_id"]
columns_j = ["buying_sight", "mid_rate", "selling", "currency_id"]


oneh_m5u_22 = m5u_22.drop(columns_u, axis=1)

oneh_m5j_22 = m5j_22.drop(columns_j, axis=1)

oneh_m5_22 = pd.merge(oneh_m5u_22,oneh_m5j_22, how="inner", on="period")
oneh_m5_22["100 Dollars = JPY"] = ((oneh_m5_22["selling"].astype(float))*100)/(oneh_m5_22["buying_transfer"].astype(float))
oneh_m5_22
# Out:
#                selling buying_transfer  100 Dollars = JPY
# period
# 2022-05-03  34.6180000      26.1540000         132.362163
# 2022-05-05  34.2507000      26.0700000         131.379747
# 2022-05-06  34.5380000      25.9793000         132.944306
# 2022-05-09  34.6504000      26.0197000         133.169867
# 2022-05-10  34.7201000      26.2148000         132.444650
# 2022-05-11  34.8372000      26.2723000         132.600496
# 2022-05-12  34.8713000      26.4681000         131.748407
# 2022-05-13  34.8900000      26.5972000         131.179222
# 2022-05-17  34.8093000      26.4669000         131.520125
# 2022-05-18  34.7655000      26.4492000         131.442539
# 2022-05-19  34.7968000      26.6000000         130.815038
# 2022-05-20  34.5957000      26.5819000         130.147582
# 2022-05-23  34.4587000      26.5474000         129.800658
# 2022-05-24  34.3536000      26.4360000         129.950068
# 2022-05-25  34.3475000      26.6034000         129.109437
# ...

# %%
# 2022-M6
columns_u = ["buying_sight", "mid_rate", "buying_transfer", "currency_id"]
columns_j = ["buying_sight", "mid_rate", "selling", "currency_id"]


oneh_m6u_22 = m6u_22.drop(columns_u, axis=1)

oneh_m6j_22 = m6j_22.drop(columns_j, axis=1)

oneh_m6_22 = pd.merge(oneh_m6u_22,oneh_m6j_22, how="inner", on="period")
oneh_m6_22["100 Dollars = JPY"] = ((oneh_m6_22["selling"].astype(float))*100)/(oneh_m6_22["buying_transfer"].astype(float))
oneh_m6_22
# Out:
#                selling buying_transfer  100 Dollars = JPY
# period
# 2022-06-01  34.4972000      26.2616000         131.359856
# 2022-06-02  34.5529000      26.1192000         132.289274
# 2022-06-06  34.5743000      26.0149000         132.901914
# 2022-06-07  34.6197000      25.6492000         134.973800
# 2022-06-08  34.6376000      25.5782000         135.418442
# 2022-06-09  34.6936000      25.4187000         136.488491
# 2022-06-10  34.8144000      25.5315000         136.358616
# 2022-06-13  34.9847000      25.4910000         137.243341
# 2022-06-14  35.1114000      25.6660000         136.801216
# 2022-06-15  35.2271000      25.6454000         137.362256
# 2022-06-16  35.1226000      25.6926000         136.703175
# 2022-06-17  35.3562000      26.0041000         135.963944
# 2022-06-20  35.4485000      25.8212000         137.284479
# 2022-06-21  35.5310000      25.8571000         137.412935
# 2022-06-22  35.6243000      25.7001000         138.615414
# ...

# %%
# 2022-M7
columns_u = ["buying_sight", "mid_rate", "buying_transfer", "currency_id"]
columns_j = ["buying_sight", "mid_rate", "selling", "currency_id"]


oneh_m7u_22 = m7u_22.drop(columns_u, axis=1)

oneh_m7j_22 = m7j_22.drop(columns_j, axis=1)

oneh_m7_22 = pd.merge(oneh_m7u_22,oneh_m7j_22, how="inner", on="period")
oneh_m7_22["100 Dollars = JPY"] = ((oneh_m7_22["selling"].astype(float))*100)/(oneh_m7_22["buying_transfer"].astype(float))
oneh_m7_22
# Out:
#                selling buying_transfer  100 Dollars = JPY
# period
# 2022-07-01  35.6658000      25.8701000         137.864948
# 2022-07-04  35.8566000      26.0761000         137.507526
# 2022-07-05  35.8652000      25.8855000         138.553244
# 2022-07-06  36.1566000      26.2720000         137.624086
# 2022-07-07  36.3622000      26.3337000         138.082381
# 2022-07-08  36.1575000      26.1753000         138.135953
# 2022-07-11  36.1419000      25.9443000         139.305743
# 2022-07-12  36.4518000      26.1138000         139.588264
# 2022-07-14  36.4962000      25.9608000         140.581954
# 2022-07-15  36.8023000      26.0436000         141.310341
# 2022-07-18  36.7620000      26.1645000         140.503354
# 2022-07-19  36.8318000      26.2235000         140.453410
# 2022-07-20  36.8055000      26.2070000         140.441485
# 2022-07-21  36.9392000      26.2496000         140.722906
# 2022-07-22  36.9927000      26.4343000         139.942045
# ...

# %%
# 2022-M7
columns_u = ["buying_sight", "mid_rate", "buying_transfer", "currency_id"]
columns_j = ["buying_sight", "mid_rate", "selling", "currency_id"]


oneh_m8u_22 = m8u_22.drop(columns_u, axis=1)

oneh_m8j_22 = m8j_22.drop(columns_j, axis=1)

oneh_m8_22 = pd.merge(oneh_m8u_22,oneh_m8j_22, how="inner", on="period")
oneh_m8_22["100 Dollars = JPY"] = ((oneh_m8_22["selling"].astype(float))*100)/(oneh_m8_22["buying_transfer"].astype(float))
oneh_m8_22
# Out:
#                selling buying_transfer  100 Dollars = JPY
# period
# 2022-08-01  36.3922000      27.0026000         134.772948
# 2022-08-02  36.2466000      27.2656000         132.938941
# 2022-08-03  36.3690000      26.8180000         135.614140
# 2022-08-04  36.3148000      26.6765000         136.130302
# 2022-08-05  35.8500000      26.4571000         135.502379
# 2022-08-08  35.9454000      26.1445000         137.487426
# 2022-08-09  35.6357000      25.9744000         137.195469
# 2022-08-10  35.5954000      25.8965000         137.452552
# 2022-08-11  35.4883000      26.2251000         135.321886
# 2022-08-15  35.5781000      26.2331000         135.622934
# 2022-08-16  35.6257000      26.2577000         135.677154
# 2022-08-17  35.5565000      26.0336000         136.579267
# 2022-08-18  35.7250000      25.9977000         137.416002
# 2022-08-19  35.8858000      25.8958000         138.577684
# 2022-08-22  36.0947000      25.8514000         139.623773
# ...

# %%
# 2022-M9
columns_u = ["buying_sight", "mid_rate", "buying_transfer", "currency_id"]
columns_j = ["buying_sight", "mid_rate", "selling", "currency_id"]


oneh_m9u_22 = m9u_22.drop(columns_u, axis=1)

oneh_m9j_22 = m9j_22.drop(columns_j, axis=1)

oneh_m9_22 = pd.merge(oneh_m9u_22,oneh_m9j_22, how="inner", on="period")
oneh_m9_22["100 Dollars = JPY"] = ((oneh_m9_22["selling"].astype(float))*100)/(oneh_m9_22["buying_transfer"].astype(float))
oneh_m9_22
# Out:
#                selling buying_transfer  100 Dollars = JPY
# period
# 2022-09-01  36.8551000      25.9683000         141.923422
# 2022-09-02  36.9511000      25.9233000         142.540109
# 2022-09-05  36.9008000      25.8597000         142.696164
# 2022-09-06  36.6024000      25.5973000         142.993206
# 2022-09-07  36.9009000      25.2452000         146.169965
# 2022-09-08  36.6190000      24.9878000         146.547515
# 2022-09-09  36.4993000      25.0256000         145.847852
# 2022-09-12  36.5822000      25.1876000         145.238927
# 2022-09-13  36.4610000      25.1346000         145.062981
# 2022-09-14  36.8491000      25.0877000         146.881141
# 2022-09-15  36.8649000      25.2808000         145.821730
# 2022-09-16  37.1848000      25.5054000         145.791872
# 2022-09-19  37.0806000      25.4570000         145.659740
# 2022-09-20  37.0863000      25.4512000         145.715330
# 2022-09-21  37.2874000      25.5025000         146.210764
# ...

# %%
# 2022-M10
columns_u = ["buying_sight", "mid_rate", "buying_transfer", "currency_id"]
columns_j = ["buying_sight", "mid_rate", "selling", "currency_id"]


oneh_m10u_22 = m10u_22.drop(columns_u, axis=1)

oneh_m10j_22 = m10j_22.drop(columns_j, axis=1)

oneh_m10_22 = pd.merge(oneh_m10u_22,oneh_m10j_22, how="inner", on="period")
oneh_m10_22["100 Dollars = JPY"] = ((oneh_m10_22["selling"].astype(float))*100)/(oneh_m10_22["buying_transfer"].astype(float))
oneh_m10_22
# Out:
#                selling buying_transfer  100 Dollars = JPY
# period
# 2022-10-03  38.1710000      25.8978000         147.390898
# 2022-10-04  37.9276000      25.7530000         147.274492
# 2022-10-05  37.5592000      25.6215000         146.592510
# 2022-10-06  37.4588000      25.4624000         147.114176
# 2022-10-07  37.5947000      25.4953000         147.457374
# 2022-10-10  37.9266000      25.6440000         147.896584
# 2022-10-11  38.2615000      25.8212000         148.178628
# 2022-10-12  38.3251000      25.7747000         148.692710
# 2022-10-17  38.3293000      25.3540000         151.176540
# 2022-10-18  38.2199000      25.2372000         151.442712
# 2022-10-19  38.2314000      25.1850000         151.802263
# 2022-10-20  38.4745000      25.2119000         152.604524
# 2022-10-21  38.5005000      25.1836000         152.879255
# 2022-10-25  38.3593000      25.3157000         151.523758
# 2022-10-26  38.1110000      25.3079000         150.589342
# ...

# %%
# 2022-M11
columns_u = ["buying_sight", "mid_rate", "buying_transfer", "currency_id"]
columns_j = ["buying_sight", "mid_rate", "selling", "currency_id"]


oneh_m11u_22 = m11u_22.drop(columns_u, axis=1)

oneh_m11j_22 = m11j_22.drop(columns_j, axis=1)

oneh_m11_22 = pd.merge(oneh_m11u_22,oneh_m11j_22, how="inner", on="period")
oneh_m11_22["100 Dollars = JPY"] = ((oneh_m11_22["selling"].astype(float))*100)/(oneh_m11_22["buying_transfer"].astype(float))
oneh_m11_22
# Out:
#                selling buying_transfer  100 Dollars = JPY
# period
# 2022-11-01  38.0886000      25.2665000         150.747432
# 2022-11-02  37.8164000      25.2193000         149.950237
# 2022-11-03  37.9901000      25.3388000         149.928568
# 2022-11-04  37.9039000      25.1537000         150.689163
# 2022-11-07  37.5707000      25.0895000         149.746707
# 2022-11-08  37.4936000      25.1220000         149.246079
# 2022-11-09  37.0231000      24.9871000         148.168855
# 2022-11-10  37.0418000      24.8857000         148.847732
# 2022-11-11  36.1859000      25.0377000         144.525655
# 2022-11-14  35.9930000      25.4048000         141.677951
# 2022-11-15  35.8595000      25.1195000         142.755628
# 2022-11-16  35.8524000      25.1909000         142.322823
# 2022-11-17  35.9994000      25.3508000         142.004986
# 2022-11-18  36.0064000      25.2759000         142.453483
# 2022-11-21  36.2110000      25.3179000         143.025290
# ...

# %%
# 2022-M12
columns_u = ["buying_sight", "mid_rate", "buying_transfer", "currency_id"]
columns_j = ["buying_sight", "mid_rate", "selling", "currency_id"]


oneh_m12u_22 = m12u_22.drop(columns_u, axis=1)

oneh_m12j_22 = m12j_22.drop(columns_j, axis=1)

oneh_m12_22 = pd.merge(oneh_m12u_22,oneh_m12j_22, how="inner", on="period")
oneh_m12_22["100 Dollars = JPY"] = ((oneh_m12_22["selling"].astype(float))*100)/(oneh_m12_22["buying_transfer"].astype(float))
oneh_m12_22
# Out:
#                selling buying_transfer  100 Dollars = JPY
# period
# 2022-12-01  35.1691000      25.2860000         139.085265
# 2022-12-02  34.9573000      25.3910000         137.675948
# 2022-12-06  35.1816000      25.2683000         139.232160
# 2022-12-07  35.2407000      25.2334000         139.658944
# 2022-12-08  34.9921000      25.1096000         139.357457
# 2022-12-09  34.9137000      25.1919000         138.590976
# 2022-12-13  34.9431000      24.9446000         140.082824
# 2022-12-14  34.7803000      25.2079000         137.973810
# 2022-12-15  34.9006000      25.2897000         138.003219
# 2022-12-16  35.1858000      25.1692000         139.797054
# 2022-12-19  34.9720000      25.2482000         138.512844
# 2022-12-20  35.0685000      25.4573000         137.754200
# 2022-12-21  34.9148000      25.9753000         134.415387
# 2022-12-22  34.8511000      25.9625000         134.236302
# 2022-12-23  34.9926000      25.9231000         134.986171
# ...

# %% [markdown]
# ให้ทําการคํานวณว่าถ้ามีเงิน 500 EUR จะแลกเป็นเงินสกุลเยนได้เท่าไหร่ โดยพิจารณาเป็นอัตรารายเดือนของปี
# 2023 คํานวณเฉพาะค่า buy_sight และ mid_rate

# %%
#2023-m1
columns_e = ["buying_sight", "mid_rate", "buying_transfer", "currency_id"]
columns_j = ["buying_transfer", "mid_rate", "selling", "currency_id"]

fiveh_m1e = m1e.drop(columns_e, axis=1)

fiveh_m1j = m1j.drop(columns_j, axis=1)

fiveh_m1 = pd.merge(fiveh_m1e,fiveh_m1j, how="inner", on="period")
fiveh_m1["500 EUR = JPY"] = ((fiveh_m1["selling"].astype(float))*500)/(fiveh_m1["buying_sight"].astype(float))
fiveh_m1
# Out:
#                selling buying_sight  500 EUR = JPY
# period
# 2023-01-03  37.0397000   25.9944000     712.455375
# 2023-01-04  36.5698000   25.7310000     710.617543
# 2023-01-05  36.3323000   25.1989000     720.910437
# 2023-01-06  36.1566000   24.9667000     724.096497
# 2023-01-09  36.1512000   24.9896000     723.324903
# 2023-01-10  36.2519000   24.9295000     727.088389
# 2023-01-11  36.3433000   24.8759000     730.492163
# 2023-01-12  36.2662000   24.8664000     729.220957
# 2023-01-13  36.2920000   25.2446000     718.807190
# 2023-01-16  36.0049000   25.2533000     712.875149
# 2023-01-17  36.1649000   25.2357000     716.542438
# 2023-01-18  36.0412000   24.9927000     721.034542
# 2023-01-19  36.0611000   25.3067000     712.481280
# 2023-01-20  35.9602000   25.0366000     718.152625
# 2023-01-23  35.9711000   24.7880000     725.574875
# 2023-01-24  35.9921000   24.6985000     728.629269
# 2023-01-25  36.0944000   24.7193000     730.085399
# ...

# %%
#2023-m2
columns_e = ["buying_sight", "mid_rate", "buying_transfer", "currency_id"]
columns_j = ["buying_transfer", "mid_rate", "selling", "currency_id"]

fiveh_m2e = m2e.drop(columns_e, axis=1)

fiveh_m2j = m2j.drop(columns_j, axis=1)

fiveh_m2 = pd.merge(fiveh_m2e,fiveh_m2j, how="inner", on="period")
fiveh_m2["500 EUR = JPY"] = ((fiveh_m2["selling"].astype(float))*500)/(fiveh_m2["buying_sight"].astype(float))
fiveh_m2
# Out:
#                selling buying_sight  500 EUR = JPY
# period
# 2023-02-01  36.0891000   24.8377000     726.498428
# 2023-02-02  36.3945000   24.9940000     728.064736
# 2023-02-03  36.3312000   25.2093000     720.591210
# 2023-02-06  36.5391000   24.9441000     732.419690
# 2023-02-07  36.4796000   24.9769000     730.266766
# 2023-02-08  36.3325000   25.1055000     723.596423
# 2023-02-09  36.3393000   25.0354000     725.758326
# 2023-02-10  36.4706000   25.1252000     725.777307
# 2023-02-13  36.4168000   25.1693000     723.436885
# 2023-02-14  36.6600000   25.1415000     729.073444
# 2023-02-15  36.8721000   25.1594000     732.769859
# 2023-02-16  37.0101000   25.1260000     736.490090
# 2023-02-17  37.1119000   25.1887000     736.677558
# 2023-02-20  37.1165000   25.1678000     737.380701
# 2023-02-21  37.2286000   25.2492000     737.223358
# 2023-02-22  37.2890000   25.2576000     738.173857
# 2023-02-23  37.0929000   25.2018000     735.917673
# ...

# %%
#2023-m3
columns_e = ["buying_sight", "mid_rate", "buying_transfer", "currency_id"]
columns_j = ["buying_transfer", "mid_rate", "selling", "currency_id"]

fiveh_m3e = m3e.drop(columns_e, axis=1)

fiveh_m3j = m3j.drop(columns_j, axis=1)

fiveh_m3 = pd.merge(fiveh_m3e,fiveh_m3j, how="inner", on="period")
fiveh_m3["500 EUR = JPY"] = ((fiveh_m3["selling"].astype(float))*500)/(fiveh_m3["buying_sight"].astype(float))
fiveh_m3
# Out:
#                selling buying_sight  500 EUR = JPY
# period
# 2023-03-01  37.4886000   25.3048000     740.740887
# 2023-03-02  37.4609000   25.0993000     746.253880
# 2023-03-03  37.2536000   25.0021000     745.009419
# 2023-03-07  37.2570000   24.9810000     745.706737
# 2023-03-08  37.3637000   25.0773000     744.970551
# 2023-03-09  37.3632000   25.1418000     743.049424
# 2023-03-10  37.4892000   25.2783000     741.529296
# 2023-03-13  37.3863000   25.3323000     737.917599
# 2023-03-14  37.3173000   25.4222000     733.951035
# 2023-03-15  37.4142000   25.2538000     740.763766
# 2023-03-16  36.9232000   25.5055000     723.828194
# 2023-03-17  36.7924000   25.2879000     727.470450
# 2023-03-20  36.7055000   25.4232000     721.889849
# 2023-03-21  36.9268000   25.5616000     722.310028
# 2023-03-22  37.4508000   25.5961000     731.572388
# 2023-03-23  37.5178000   25.6833000     730.392901
# 2023-03-24  37.2485000   25.7277000     723.898755
# ...

# %%
#2023-m4
columns_e = ["buying_sight", "mid_rate", "buying_transfer", "currency_id"]
columns_j = ["buying_transfer", "mid_rate", "selling", "currency_id"]

fiveh_m4e = m4e.drop(columns_e, axis=1)

fiveh_m4j = m4j.drop(columns_j, axis=1)

fiveh_m4 = pd.merge(fiveh_m4e,fiveh_m4j, how="inner", on="period")
fiveh_m4["500 EUR = JPY"] = ((fiveh_m4["selling"].astype(float))*500)/(fiveh_m4["buying_sight"].astype(float))
fiveh_m4
# Out:
#                selling buying_sight  500 EUR = JPY
# period
# 2023-04-03  37.4925000   25.3674000     738.989806
# 2023-04-04  37.6748000   25.3519000     743.037011
# 2023-04-05  37.5616000   25.3468000     740.953493
# 2023-04-07  37.5954000   25.4474000     738.688432
# 2023-04-10  37.7615000   25.4208000     742.728396
# 2023-04-11  37.7228000   25.2739000     746.279759
# 2023-04-12  37.7754000   25.1596000     750.715433
# 2023-04-17  38.0605000   25.1833000     755.669432
# 2023-04-18  38.0294000   25.1606000     755.733170
# 2023-04-19  38.0545000   25.1344000     757.020259
# 2023-04-20  38.0551000   25.1237000     757.354609
# 2023-04-21  37.9881000   25.2225000     753.059768
# 2023-04-24  38.1989000   25.2776000     755.587951
# 2023-04-25  38.2877000   25.1267000     761.892728
# 2023-04-26  38.0212000   25.2271000     753.578493
# 2023-04-27  38.0471000   25.1010000     757.880164
# 2023-04-28  37.9764000   24.9221000     761.902087

# %%
#2023-m5
columns_e = ["buying_sight", "mid_rate", "buying_transfer", "currency_id"]
columns_j = ["buying_transfer", "mid_rate", "selling", "currency_id"]

fiveh_m5e = m5e.drop(columns_e, axis=1)

fiveh_m5j = m5j.drop(columns_j, axis=1)

fiveh_m5 = pd.merge(fiveh_m5e,fiveh_m5j, how="inner", on="period")
fiveh_m5["500 EUR = JPY"] = ((fiveh_m5["selling"].astype(float))*500)/(fiveh_m5["buying_sight"].astype(float))
fiveh_m5
# Out:
#                selling buying_sight  500 EUR = JPY
# period
# 2023-05-02  37.8819000   24.4524000     774.604947
# 2023-05-03  37.8706000   24.5668000     770.767866
# 2023-05-08  37.7903000   24.6975000     765.063266
# 2023-05-09  37.4382000   24.5377000     762.871011
# 2023-05-10  37.3058000   24.4486000     762.943481
# 2023-05-11  37.2952000   24.6773000     755.658034
# 2023-05-12  37.3834000   24.7333000     755.730129
# 2023-05-15  37.0821000   24.4140000     759.443352
# 2023-05-16  37.1888000   24.4502000     760.500937
# 2023-05-17  37.4857000   24.5818000     762.468574
# 2023-05-18  37.4383000   24.4321000     766.170325
# 2023-05-19  37.4851000   24.4510000     766.535111
# 2023-05-22  37.5768000   24.5377000     765.695236
# 2023-05-23  37.7604000   24.5282000     769.734428
# 2023-05-24  37.5860000   24.5390000     765.842129
# 2023-05-25  37.6144000   24.4183000     770.209228
# 2023-05-26  37.5674000   24.3298000     772.044982
# ...

# %%
#2023-m6
columns_e = ["buying_sight", "mid_rate", "buying_transfer", "currency_id"]
columns_j = ["buying_transfer", "mid_rate", "selling", "currency_id"]

fiveh_m6e = m6e.drop(columns_e, axis=1)

fiveh_m6j = m6j.drop(columns_j, axis=1)

fiveh_m6 = pd.merge(fiveh_m6e,fiveh_m6j, how="inner", on="period")
fiveh_m6["500 EUR = JPY"] = ((fiveh_m6["selling"].astype(float))*500)/(fiveh_m6["buying_sight"].astype(float))
fiveh_m6
# Out:
#                selling buying_sight  500 EUR = JPY
# period
# 2023-06-01  37.4573000   24.4883000     764.799925
# 2023-06-02  37.5831000   24.5065000     766.798604
# 2023-06-06  37.6057000   24.4792000     768.115380
# 2023-06-07  37.5208000   24.5243000     764.971885
# 2023-06-08  37.7022000   24.4897000     769.756265
# 2023-06-09  37.6655000   24.4425000     770.491971
# 2023-06-12  37.5806000   24.4052000     769.930179
# 2023-06-13  37.5882000   24.3618000     771.457774
# 2023-06-14  37.7228000   24.3007000     776.166942
# 2023-06-15  38.0193000   24.2907000     782.589633
# 2023-06-16  38.2734000   24.2473000     789.230141
# 2023-06-19  38.3148000   24.0993000     794.935952
# 2023-06-20  38.3270000   24.0568000     796.593894
# 2023-06-21  38.3809000   24.1934000     793.210132
# 2023-06-22  38.7118000   24.1794000     800.512006
# 2023-06-23  38.8367000   24.2077000     802.155926
# 2023-06-26  38.7575000   24.1235000     803.314196
# ...

# %%
#2023-m7
columns_e = ["buying_sight", "mid_rate", "buying_transfer", "currency_id"]
columns_j = ["buying_transfer", "mid_rate", "selling", "currency_id"]

fiveh_m7e = m7e.drop(columns_e, axis=1)

fiveh_m7j = m7j.drop(columns_j, axis=1)

fiveh_m7 = pd.merge(fiveh_m7e,fiveh_m7j, how="inner", on="period")
fiveh_m7["500 EUR = JPY"] = ((fiveh_m7["selling"].astype(float))*500)/(fiveh_m7["buying_sight"].astype(float))
fiveh_m7
# Out:
#                selling buying_sight  500 EUR = JPY
# period
# 2023-07-03  38.7191000   23.9595000     808.011436
# 2023-07-04  38.5060000   23.7791000     809.660584
# 2023-07-05  38.3396000   23.7269000     807.935297
# 2023-07-06  38.4436000   23.9151000     803.751605
# 2023-07-07  38.7358000   24.0590000     805.016834
# 2023-07-10  38.8626000   24.2067000     802.724039
# 2023-07-11  38.8015000   24.3152000     797.885685
# 2023-07-12  38.7543000   24.5013000     790.862118
# 2023-07-13  38.9216000   24.5350000     793.185246
# 2023-07-14  39.2200000   24.6841000     794.438525
# 2023-07-17  39.2672000   24.5866000     798.548803
# 2023-07-18  38.9534000   24.3641000     799.401579
# 2023-07-19  38.5697000   24.0425000     802.115005
# 2023-07-20  38.4175000   23.9439000     802.239819
# 2023-07-21  38.5274000   24.0199000     801.989184
# 2023-07-24  38.6915000   23.9393000     808.116779
# 2023-07-25  38.5683000   23.9757000     804.320625
# ...

# %%
#2023-m8
columns_e = ["buying_sight", "mid_rate", "buying_transfer", "currency_id"]
columns_j = ["buying_transfer", "mid_rate", "selling", "currency_id"]

fiveh_m8e = m8e.drop(columns_e, axis=1)

fiveh_m8j = m8j.drop(columns_j, axis=1)

fiveh_m8 = pd.merge(fiveh_m8e,fiveh_m8j, how="inner", on="period")
fiveh_m8["500 EUR = JPY"] = ((fiveh_m8["selling"].astype(float))*500)/(fiveh_m8["buying_sight"].astype(float))
fiveh_m8
# Out:
#                selling buying_sight  500 EUR = JPY
# period
# 2023-08-02  38.0888000   23.6204000     806.269157
# 2023-08-03  38.1053000   23.6413000     805.905344
# 2023-08-04  38.3300000   23.8888000     802.258799
# 2023-08-07  38.5422000   24.0731000     800.524237
# 2023-08-08  38.7332000   23.9885000     807.328512
# 2023-08-09  38.7191000   23.9800000     807.320684
# 2023-08-10  38.8860000   23.9629000     811.379257
# 2023-08-11  38.9638000   23.8367000     817.306926
# 2023-08-15  38.8995000   23.8269000     816.293769
# 2023-08-16  39.0043000   23.9204000     815.293641
# 2023-08-17  38.9799000   23.8596000     816.859880
# 2023-08-18  38.8882000   23.9110000     813.186400
# 2023-08-21  38.7804000   23.8712000     812.284259
# 2023-08-22  38.6309000   23.6473000     816.814182
# 2023-08-23  38.2499000   23.6077000     810.114920
# 2023-08-24  38.2463000   23.6720000     807.838374
# 2023-08-25  38.1880000   23.6434000     807.582666
# ...

# %%
#2023-m9
columns_e = ["buying_sight", "mid_rate", "buying_transfer", "currency_id"]
columns_j = ["buying_transfer", "mid_rate", "selling", "currency_id"]

fiveh_m9e = m9e.drop(columns_e, axis=1)

fiveh_m9j = m9j.drop(columns_j, axis=1)

fiveh_m9 = pd.merge(fiveh_m9e,fiveh_m9j, how="inner", on="period")
fiveh_m9["500 EUR = JPY"] = ((fiveh_m9["selling"].astype(float))*500)/(fiveh_m9["buying_sight"].astype(float))
fiveh_m9
# Out:
#                selling buying_sight  500 EUR = JPY
# period
# 2023-09-01  38.3343000   23.6405000     810.775999
# 2023-09-04  38.2440000   23.6409000     808.852455
# 2023-09-05  38.4926000   23.6926000     812.333809
# 2023-09-06  38.4444000   23.6401000     813.118388
# 2023-09-07  38.4954000   23.7164000     811.577642
# 2023-09-08  38.4327000   23.7627000     808.677044
# 2023-09-11  38.4261000   23.8076000     807.013307
# 2023-09-12  38.5394000   23.8376000     808.374165
# 2023-09-13  38.7138000   23.7741000     814.201168
# 2023-09-14  38.7141000   23.8735000     810.817434
# 2023-09-15  38.4301000   23.8724000     804.906503
# 2023-09-18  38.3998000   23.7641000     807.937183
# 2023-09-19  38.6007000   23.8416000     809.524109
# 2023-09-20  38.9971000   24.0404000     811.074275
# 2023-09-21  38.8765000   23.9832000     810.494429
# 2023-09-22  38.8549000   24.0413000     808.086501
# 2023-09-25  38.6734000   23.8399000     811.106590
# ...

# %%
#2023-m10
columns_e = ["buying_sight", "mid_rate", "buying_transfer", "currency_id"]
columns_j = ["buying_transfer", "mid_rate", "selling", "currency_id"]

fiveh_m10e = m10e.drop(columns_e, axis=1)

fiveh_m10j = m10j.drop(columns_j, axis=1)

fiveh_m10 = pd.merge(fiveh_m10e,fiveh_m10j, how="inner", on="period")
fiveh_m10["500 EUR = JPY"] = ((fiveh_m10["selling"].astype(float))*500)/(fiveh_m10["buying_sight"].astype(float))
fiveh_m10
# Out:
#                selling buying_sight  500 EUR = JPY
# period
# 2023-10-02  39.2234000   24.1846000     810.916864
# 2023-10-03  39.1967000   24.3139000     806.055384
# 2023-10-04  39.2297000   24.5073000     800.367646
# 2023-10-05  39.1698000   24.4004000     802.646678
# 2023-10-06  39.3119000   24.4631000     803.493834
# 2023-10-09  39.4780000   24.4243000     808.170551
# 2023-10-10  39.3624000   24.4039000     806.477653
# 2023-10-11  39.0500000   24.0899000     810.505648
# 2023-10-12  38.8244000   23.8820000     812.838121
# 2023-10-16  38.5223000   23.8724000     806.837603
# 2023-10-17  38.7568000   23.9331000     809.690345
# 2023-10-18  38.7538000   23.8794000     811.448361
# 2023-10-19  38.7115000   23.8914000     810.155537
# 2023-10-20  38.9144000   23.9179000     813.499513
# 2023-10-24  38.9809000   23.7572000     820.401815
# 2023-10-25  38.6321000   23.7094000     814.700077
# 2023-10-26  38.6820000   23.7321000     814.972126
# ...

# %%
#2023-m11
columns_e = ["buying_sight", "mid_rate", "buying_transfer", "currency_id"]
columns_j = ["buying_transfer", "mid_rate", "selling", "currency_id"]

fiveh_m11e = m11e.drop(columns_e, axis=1)

fiveh_m11j = m11j.drop(columns_j, axis=1)

fiveh_m11 = pd.merge(fiveh_m11e,fiveh_m11j, how="inner", on="period")
fiveh_m11["500 EUR = JPY"] = ((fiveh_m11["selling"].astype(float))*500)/(fiveh_m11["buying_sight"].astype(float))
fiveh_m11
# Out:
#                selling buying_sight  500 EUR = JPY
# period
# 2023-11-01  38.6857000   23.5282000     822.113464
# 2023-11-02  38.5259000   23.5161000     819.138803
# 2023-11-03  38.4545000   23.4271000     820.726851
# 2023-11-06  38.4052000   23.2899000     824.503325
# 2023-11-07  38.4010000   23.2020000     827.536419
# 2023-11-08  38.3189000   23.1642000     827.114686
# 2023-11-09  38.3468000   23.0885000     830.430734
# 2023-11-10  38.5590000   23.2850000     827.979386
# 2023-11-13  38.8565000   23.3358000     832.551273
# 2023-11-14  38.9475000   23.4010000     832.175975
# 2023-11-15  38.9771000   23.1696000     841.125872
# 2023-11-16  38.9536000   23.0997000     843.162465
# 2023-11-17  38.5383000   22.9840000     838.372346
# 2023-11-20  38.6360000   23.0795000     837.019866
# 2023-11-21  38.8126000   23.3081000     832.598968
# 2023-11-22  38.7707000   23.3161000     831.414773
# 2023-11-23  38.7438000   23.2188000     834.319603
# ...

# %%
#2023-m12
columns_e = ["buying_sight", "mid_rate", "buying_transfer", "currency_id"]
columns_j = ["buying_transfer", "mid_rate", "selling", "currency_id"]

fiveh_m12e = m12e.drop(columns_e, axis=1)

fiveh_m12j = m12j.drop(columns_j, axis=1)

fiveh_m12 = pd.merge(fiveh_m12e,fiveh_m12j, how="inner", on="period")
fiveh_m12["500 EUR = JPY"] = ((fiveh_m12["selling"].astype(float))*500)/(fiveh_m12["buying_sight"].astype(float))
fiveh_m12
# Out:
#                selling buying_sight  500 EUR = JPY
# period
# 2023-12-01  38.7621000   23.4137000     827.765368
# 2023-12-04  38.2517000   23.3878000     817.770376
# 2023-12-06  38.2706000   23.4722000     815.232488
# 2023-12-07  38.3087000   23.6257000     810.742116
# 2023-12-08  38.3282000   24.0924000     795.441716
# 2023-12-12  38.6763000   24.0257000     804.894342
# 2023-12-13  38.9159000   24.1192000     806.741103
# 2023-12-14  38.6671000   24.3095000     795.308419
# 2023-12-15  38.6772000   24.1235000     801.649844
# 2023-12-18  38.4819000   24.1238000     797.592005
# 2023-12-19  38.5644000   24.0454000     801.908057
# 2023-12-20  38.6568000   23.8285000     811.146316
# 2023-12-21  38.6131000   24.0085000     804.154779
# 2023-12-22  38.5024000   23.9358000     804.284795
# 2023-12-25  38.4384000   23.9085000     803.864734
# 2023-12-26  38.5132000   23.8830000     806.288992
# 2023-12-27  38.4161000   23.7225000     809.697545
# ...
